# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Выгрузка-данных" data-toc-modified-id="Выгрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выгрузка данных</a></span></li><li><span><a href="#Очистка-данных" data-toc-modified-id="Очистка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Очистка данных</a></span></li><li><span><a href="#Обработка-с-помощью-BERT" data-toc-modified-id="Обработка-с-помощью-BERT-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Обработка с помощью BERT</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>CatBoost</a></span></li><li><span><a href="#LightGBM" data-toc-modified-id="LightGBM-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>LightGBM</a></span></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Определение позитивных и негативных комментариев с помощью BERT

# %% [markdown]
# Интернет-магазин запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
# <br/>
# <br/> **Цель проекта** - обучить модель классифицировать комментарии на позитивные и негативные и построить модель со значением метрики качества *F1* не меньше 0.75.

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Выгрузка данных

# %%
# !pip install lightgbm

# %%
# !pip install catboost

# %%
# !pip install torch

# %%
# !pip install transformers

# %% [markdown]
# Импортируем все библиотеки и инструменты, а также загрузим Датафрейм и выведем первые строки на экран.

# %%
import pandas as pd
import re
import nltk.corpus
import numpy as np
import warnings
import torch
import transformers as ppb
from tqdm import tqdm
from tqdm import notebook
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import f1_score
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\maria\Downloads\\toxic_comments.csv')
display(df.head())
# Out:
#                                                 text  toxic
# 0  Explanation\nWhy the edits made under my usern...      0
# 1  D'aww! He matches this background colour I'm s...      0
# 2  Hey man, I'm really not trying to edit war. It...      0
# 3  "\nMore\nI can't make any real suggestions on ...      0
# 4  You, sir, are my hero. Any chance you remember...      0

# %% [markdown]
# Убедимся, что нет пропущенных значений и дубликатов.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159571 entries, 0 to 159570
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    159571 non-null  object
#  1   toxic   159571 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Так как в данных слишком много строк, возьмём из них только 1000 для оперативности.

# %%
df_new = df.sample(1000).reset_index(drop=True)

# %% [markdown]
# Пропущенных значений и дубликатов нет, но по первым пяти строкам видно, что в тексте есть много лишних символов, знаков препинаний и стоп-слов. Проведём очистку данных.

# %% [markdown]
# ### Очистка данных

# %% [markdown]
# Напишем функцию для очистки данных от символов, чисел и с переводом текста в нижний регистр.

# %%
def  clean_text(df, text_field, new_text_field_name):
    # приводим текст в нижний регистр
    df[new_text_field_name] = df[text_field].str.lower()
    # убираем знаки препинания и символы
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", " ", elem))  
    # убираем числа
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    return df
data_clean = clean_text(df_new, 'text', 'text_clean')
data_clean = data_clean.drop('text', axis=1)
data_clean.head()
# Out:
#    toxic                                         text_clean
# 0      0      kotniski  it seems that varsovian embarked...
# 1      0  vandalism on cheap trick  putting back an albu...
# 2      0    i agree completely that policy debate belong...
# 3      0     if you look at file stephania  jpg now  you...
# 4      0     i think i fixed the grammar   although i m ...

# %%
# убираем стоп-слова
nltk.download('stopwords')
stop = stopwords.words('english')
data_clean['text_clean'] = data_clean['text_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maria\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    toxic                                         text_clean
# 0      0  kotniski seems varsovian embarked mass project...
# 1      0  vandalism cheap trick putting back album relea...
# 2      0  agree completely policy debate belongs somewhe...
# 3      0  look file stephania jpg see originally uploade...
# 4      0      think fixed grammar although sure missed hami

# %% [markdown]
# Данные очищены, выбраны и готовы к обработке с помощью BERT.

# %% [markdown]
# ### Обработка с помощью BERT

# %% [markdown]
# Импортируем предварительно обученную модели BERT и токенизатор.

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.BertModel, ppb.BertTokenizer, 'unitary/toxic-bert')

# %%
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
# Out:
# Some weights of the model checkpoint at unitary/toxic-bert were not used when initializing BertModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# Токенизируем набор данных и сделаем все векторы одинакового размера, дополнив короткие предложения идентификатором токена 0. Далее отбросим нулевые токены и «создадим маску» для действительно важных токенов, то есть укажем нулевые и не нулевые значения.

# %%
from torch.nn.utils.rnn import pad_sequence
tqdm.pandas()

tokenized = data_clean['text_clean'].progress_apply(
    lambda x: tokenizer.encode(x, max_length=512, truncation=True, add_special_tokens=True))

padded = pad_sequence([torch.as_tensor(seq) for seq in tokenized], batch_first=True)

attention_mask = padded > 0
attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 674.99it/s]
# (1000, 512)

# %%
batch_size = 100
embeddings = []
for i in notebook.tqdm(range(padded.shape[0] // batch_size)):
    batch = torch.LongTensor(padded[batch_size*i:batch_size*(i+1)])
    attention_mask_batch = torch.LongTensor(attention_mask[batch_size*i:batch_size*(i+1)])
    
    with torch.no_grad():
        batch_embeddings = model(batch, attention_mask=attention_mask_batch)
    embeddings.append(batch_embeddings[0][:,0,:].numpy())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Создадим признаки, выделим целевой признак и разделим данные на тренировочную и тестовую выборки.

# %%
features = pd.DataFrame(np.concatenate(embeddings))

# %%
target = data_clean['toxic']

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.25)

# %%
target_train.value_counts()
# Out:
# 0    675
# 1     75
# Name: toxic, dtype: int64

# %% [markdown]
# Так как в данных присутствует дисбаланс классов, решим эту проблему увеличением объектов меньшего класса. Для этого применим фукнцию `upsample`.

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    features_upsampled, target_upsampled = shuffle(features_upsampled, target_upsampled, random_state=12345)
    return features_upsampled, target_upsampled

# %%
features_upsampled, target_upsampled = upsample(features_train, target_train, 9)
target_upsampled.value_counts()
# Out:
# 0    675
# 1    675
# Name: toxic, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# В подготовке данных были выполнены следующие шаги:
# - загружены и импортированы все необходимые библиотеки и инструменты;
# - проведена загрузка данных, их очистка от символов, знаков препинания, чисел и стоп-слов;
# - сделана выборка из 1000 строк длиной меньше 512 символов;
# - проведена обработка данных с помощью BERT;
# - признаки и целевой признак разделены на тренировочную и тестовую выборки в отношении 3:1;
# - сделано увеличение выборки с токсичным комментариями для устранения дисбаланса классов.

# %% [markdown]
# ## Обучение

# %% [markdown]
# Обучим 2 модели Градиентного бустинга (CatBoost и LightGBM), Дерево решений, Случайный лес и Логистическую регрессию. Для подбора параметров и кросс-валидации используем для каждой модели `GridSearchCV()`.

# %% [markdown]
# ### CatBoost

# %%
parameters_cbc = {'learning_rate' : [0.1, 0.2, 0.3],
                 'depth' : range (10, 50, 10)
                }

# %%
# %%time

CBC = GridSearchCV(CatBoostClassifier (iterations=100), parameters_cbc, scoring='f1')
CBC.fit(features_upsampled, target_upsampled)
best_model_cbc = CBC.best_estimator_
print(CBC.best_params_)
print('f1-метрика:', CBC.best_score_)
# Out:
# 0:	learn: 0.5918080	total: 1.44s	remaining: 2m 22s
# 1:	learn: 0.5059178	total: 2.77s	remaining: 2m 15s
# 2:	learn: 0.4386475	total: 4.13s	remaining: 2m 13s
# 3:	learn: 0.3797320	total: 5.5s	remaining: 2m 12s
# 4:	learn: 0.3361156	total: 6.89s	remaining: 2m 10s
# 5:	learn: 0.3014963	total: 8.3s	remaining: 2m 10s
# 6:	learn: 0.2664965	total: 9.75s	remaining: 2m 9s
# 7:	learn: 0.2402668	total: 11.3s	remaining: 2m 9s
# 8:	learn: 0.2150024	total: 12.8s	remaining: 2m 9s
# 9:	learn: 0.1952887	total: 14.3s	remaining: 2m 8s
# 10:	learn: 0.1772457	total: 15.9s	remaining: 2m 8s
# 11:	learn: 0.1615025	total: 17.4s	remaining: 2m 7s
# 12:	learn: 0.1489524	total: 18.9s	remaining: 2m 6s
# 13:	learn: 0.1349419	total: 20.5s	remaining: 2m 5s
# 14:	learn: 0.1239527	total: 22s	remaining: 2m 4s
# 15:	learn: 0.1149380	total: 23.6s	remaining: 2m 4s
# 16:	learn: 0.1061718	total: 25.3s	remaining: 2m 3s
# 17:	learn: 0.0989627	total: 26.9s	remaining: 2m 2s
# 18:	learn: 0.0926895	total: 28.7s	remaining: 2m 2s
# 19:	learn: 0.0870399	total: 30.3s	remaining: 2m 1s
# 20:	learn: 0.0816560	total: 32s	remaining: 2m
# 21:	learn: 0.0769950	total: 33.6s	remaining: 1m 59s
# 22:	learn: 0.0720301	total: 35.3s	remaining: 1m 58s
# 23:	learn: 0.0673152	total: 37s	remaining: 1m 57s
# 24:	learn: 0.0642768	total: 38.6s	remaining: 1m 55s
# 25:	learn: 0.0605799	total: 40.4s	remaining: 1m 54s
# 26:	learn: 0.0578547	total: 42.1s	remaining: 1m 53s
# 27:	learn: 0.0557018	total: 43.9s	remaining: 1m 52s
# 28:	learn: 0.0525967	total: 45.6s	remaining: 1m 51s
# 29:	learn: 0.0503166	total: 47.3s	remaining: 1m 50s
# 30:	learn: 0.0481509	total: 48.9s	remaining: 1m 48s
# 31:	learn: 0.0462499	total: 50.6s	remaining: 1m 47s
# 32:	learn: 0.0443037	total: 52.3s	remaining: 1m 46s
# 33:	learn: 0.0424892	total: 54s	remaining: 1m 44s
# 34:	learn: 0.0411762	total: 55.7s	remaining: 1m 43s
# 35:	learn: 0.0394974	total: 57.4s	remaining: 1m 42s
# 36:	learn: 0.0382269	total: 59.2s	remaining: 1m 40s
# 37:	learn: 0.0369169	total: 1m 1s	remaining: 1m 39s
# 38:	learn: 0.0356564	total: 1m 2s	remaining: 1m 38s
# 39:	learn: 0.0345869	total: 1m 4s	remaining: 1m 36s
# 40:	learn: 0.0335901	total: 1m 6s	remaining: 1m 35s
# 41:	learn: 0.0322946	total: 1m 7s	remaining: 1m 33s
# 42:	learn: 0.0311062	total: 1m 9s	remaining: 1m 32s
# 43:	learn: 0.0302245	total: 1m 11s	remaining: 1m 30s
# 44:	learn: 0.0291904	total: 1m 12s	remaining: 1m 29s
# 45:	learn: 0.0284817	total: 1m 14s	remaining: 1m 27s
# 46:	learn: 0.0277400	total: 1m 16s	remaining: 1m 26s
# 47:	learn: 0.0270302	total: 1m 18s	remaining: 1m 24s
# 48:	learn: 0.0260660	total: 1m 20s	remaining: 1m 23s
# 49:	learn: 0.0253287	total: 1m 21s	remaining: 1m 21s
# 50:	learn: 0.0246793	total: 1m 23s	remaining: 1m 20s
# 51:	learn: 0.0241369	total: 1m 25s	remaining: 1m 18s
# 52:	learn: 0.0236500	total: 1m 26s	remaining: 1m 17s
# 53:	learn: 0.0231548	total: 1m 28s	remaining: 1m 15s
# 54:	learn: 0.0226141	total: 1m 30s	remaining: 1m 13s
# 55:	learn: 0.0218955	total: 1m 32s	remaining: 1m 12s
# 56:	learn: 0.0213133	total: 1m 33s	remaining: 1m 10s
# 57:	learn: 0.0209042	total: 1m 35s	remaining: 1m 9s
# 58:	learn: 0.0204734	total: 1m 37s	remaining: 1m 7s
# 59:	learn: 0.0199952	total: 1m 39s	remaining: 1m 6s
# 60:	learn: 0.0194390	total: 1m 40s	remaining: 1m 4s
# 61:	learn: 0.0189944	total: 1m 42s	remaining: 1m 2s
# 62:	learn: 0.0185763	total: 1m 44s	remaining: 1m 1s
# 63:	learn: 0.0181746	total: 1m 45s	remaining: 59.6s
# 64:	learn: 0.0177970	total: 1m 47s	remaining: 58s
# 65:	learn: 0.0174135	total: 1m 49s	remaining: 56.4s
# 66:	learn: 0.0170100	total: 1m 51s	remaining: 54.8s
# 67:	learn: 0.0165297	total: 1m 52s	remaining: 53.1s
# 68:	learn: 0.0162195	total: 1m 54s	remaining: 51.5s
# 69:	learn: 0.0159474	total: 1m 56s	remaining: 49.8s
# 70:	learn: 0.0155488	total: 1m 57s	remaining: 48.2s
# 71:	learn: 0.0152295	total: 1m 59s	remaining: 46.5s
# 72:	learn: 0.0149679	total: 2m 1s	remaining: 44.9s
# 73:	learn: 0.0146600	total: 2m 3s	remaining: 43.3s
# 74:	learn: 0.0143720	total: 2m 5s	remaining: 41.7s
# 75:	learn: 0.0140530	total: 2m 6s	remaining: 40s
# 76:	learn: 0.0138315	total: 2m 8s	remaining: 38.4s
# 77:	learn: 0.0135656	total: 2m 10s	remaining: 36.8s
# 78:	learn: 0.0133317	total: 2m 12s	remaining: 35.1s
# 79:	learn: 0.0131027	total: 2m 13s	remaining: 33.4s
# 80:	learn: 0.0128774	total: 2m 15s	remaining: 31.8s
# 81:	learn: 0.0127035	total: 2m 17s	remaining: 30.1s
# 82:	learn: 0.0123384	total: 2m 19s	remaining: 28.5s
# 83:	learn: 0.0121284	total: 2m 21s	remaining: 26.9s
# 84:	learn: 0.0119402	total: 2m 22s	remaining: 25.2s
# 85:	learn: 0.0117457	total: 2m 24s	remaining: 23.5s
# 86:	learn: 0.0113929	total: 2m 26s	remaining: 21.8s
# 87:	learn: 0.0112422	total: 2m 27s	remaining: 20.2s
# 88:	learn: 0.0110770	total: 2m 29s	remaining: 18.5s
# 89:	learn: 0.0108964	total: 2m 31s	remaining: 16.8s
# 90:	learn: 0.0107269	total: 2m 33s	remaining: 15.1s
# 91:	learn: 0.0105624	total: 2m 34s	remaining: 13.5s
# 92:	learn: 0.0103821	total: 2m 36s	remaining: 11.8s
# 93:	learn: 0.0102310	total: 2m 38s	remaining: 10.1s
# 94:	learn: 0.0100430	total: 2m 40s	remaining: 8.43s
# 95:	learn: 0.0098901	total: 2m 41s	remaining: 6.74s
# 96:	learn: 0.0097367	total: 2m 43s	remaining: 5.06s
# 97:	learn: 0.0095636	total: 2m 45s	remaining: 3.37s
# 98:	learn: 0.0094396	total: 2m 47s	remaining: 1.69s
# 99:	learn: 0.0092868	total: 2m 48s	remaining: 0us
# 0:	learn: 0.5847441	total: 1.65s	remaining: 2m 43s
# 1:	learn: 0.5077576	total: 3.3s	remaining: 2m 41s
# 2:	learn: 0.4388646	total: 5.04s	remaining: 2m 42s
# 3:	learn: 0.3852000	total: 6.78s	remaining: 2m 42s
# 4:	learn: 0.3373793	total: 8.52s	remaining: 2m 41s
# 5:	learn: 0.3004019	total: 10.3s	remaining: 2m 40s
# 6:	learn: 0.2671836	total: 12s	remaining: 2m 39s
# 7:	learn: 0.2407988	total: 13.7s	remaining: 2m 37s
# 8:	learn: 0.2156614	total: 15.4s	remaining: 2m 35s
# 9:	learn: 0.1940459	total: 17.2s	remaining: 2m 34s
# 10:	learn: 0.1778094	total: 19s	remaining: 2m 33s
# 11:	learn: 0.1625899	total: 20.7s	remaining: 2m 31s
# 12:	learn: 0.1490687	total: 22.4s	remaining: 2m 29s
# 13:	learn: 0.1355814	total: 24.1s	remaining: 2m 27s
# 14:	learn: 0.1259144	total: 25.8s	remaining: 2m 25s
# 15:	learn: 0.1161737	total: 27.4s	remaining: 2m 24s
# 16:	learn: 0.1079864	total: 29.1s	remaining: 2m 22s
# 17:	learn: 0.1008450	total: 30.8s	remaining: 2m 20s
# 18:	learn: 0.0938746	total: 32.6s	remaining: 2m 19s
# 19:	learn: 0.0878319	total: 34.4s	remaining: 2m 17s
# 20:	learn: 0.0829055	total: 36.2s	remaining: 2m 16s
# 21:	learn: 0.0778142	total: 37.8s	remaining: 2m 14s
# 22:	learn: 0.0725449	total: 39.5s	remaining: 2m 12s
# 23:	learn: 0.0676989	total: 41.2s	remaining: 2m 10s
# 24:	learn: 0.0645355	total: 42.9s	remaining: 2m 8s
# 25:	learn: 0.0609027	total: 44.6s	remaining: 2m 6s
# 26:	learn: 0.0579081	total: 46.3s	remaining: 2m 5s
# 27:	learn: 0.0556121	total: 48.1s	remaining: 2m 3s
# 28:	learn: 0.0532185	total: 50s	remaining: 2m 2s
# 29:	learn: 0.0507126	total: 51.8s	remaining: 2m
# 30:	learn: 0.0488401	total: 53.5s	remaining: 1m 59s
# 31:	learn: 0.0463656	total: 55.2s	remaining: 1m 57s
# 32:	learn: 0.0444504	total: 56.9s	remaining: 1m 55s
# 33:	learn: 0.0427833	total: 58.6s	remaining: 1m 53s
# 34:	learn: 0.0411442	total: 1m	remaining: 1m 52s
# 35:	learn: 0.0394652	total: 1m 2s	remaining: 1m 50s
# 36:	learn: 0.0378638	total: 1m 3s	remaining: 1m 48s
# 37:	learn: 0.0362907	total: 1m 5s	remaining: 1m 47s
# 38:	learn: 0.0352029	total: 1m 7s	remaining: 1m 45s
# 39:	learn: 0.0341097	total: 1m 9s	remaining: 1m 43s
# 40:	learn: 0.0328936	total: 1m 10s	remaining: 1m 41s
# 41:	learn: 0.0317729	total: 1m 12s	remaining: 1m 40s
# 42:	learn: 0.0307929	total: 1m 14s	remaining: 1m 38s
# 43:	learn: 0.0298635	total: 1m 15s	remaining: 1m 36s
# 44:	learn: 0.0291206	total: 1m 17s	remaining: 1m 34s
# 45:	learn: 0.0284419	total: 1m 19s	remaining: 1m 33s
# 46:	learn: 0.0276023	total: 1m 21s	remaining: 1m 31s
# 47:	learn: 0.0268493	total: 1m 22s	remaining: 1m 29s
# 48:	learn: 0.0261574	total: 1m 24s	remaining: 1m 28s
# 49:	learn: 0.0254435	total: 1m 26s	remaining: 1m 26s
# 50:	learn: 0.0248311	total: 1m 28s	remaining: 1m 24s
# 51:	learn: 0.0243605	total: 1m 29s	remaining: 1m 22s
# 52:	learn: 0.0238922	total: 1m 31s	remaining: 1m 21s
# 53:	learn: 0.0233806	total: 1m 33s	remaining: 1m 19s
# 54:	learn: 0.0227665	total: 1m 34s	remaining: 1m 17s
# 55:	learn: 0.0221089	total: 1m 36s	remaining: 1m 15s
# 56:	learn: 0.0215449	total: 1m 38s	remaining: 1m 14s
# 57:	learn: 0.0207987	total: 1m 40s	remaining: 1m 12s
# 58:	learn: 0.0203146	total: 1m 42s	remaining: 1m 10s
# 59:	learn: 0.0199183	total: 1m 43s	remaining: 1m 9s
# 60:	learn: 0.0195739	total: 1m 45s	remaining: 1m 7s
# 61:	learn: 0.0190677	total: 1m 47s	remaining: 1m 5s
# 62:	learn: 0.0187315	total: 1m 48s	remaining: 1m 3s
# 63:	learn: 0.0182815	total: 1m 50s	remaining: 1m 2s
# 64:	learn: 0.0178529	total: 1m 52s	remaining: 1m
# 65:	learn: 0.0174874	total: 1m 54s	remaining: 58.8s
# 66:	learn: 0.0171809	total: 1m 55s	remaining: 57s
# 67:	learn: 0.0168785	total: 1m 57s	remaining: 55.3s
# 68:	learn: 0.0164697	total: 1m 59s	remaining: 53.6s
# 69:	learn: 0.0161816	total: 2m	remaining: 51.8s
# 70:	learn: 0.0158042	total: 2m 2s	remaining: 50.1s
# 71:	learn: 0.0155249	total: 2m 4s	remaining: 48.3s
# 72:	learn: 0.0152278	total: 2m 5s	remaining: 46.5s
# 73:	learn: 0.0149450	total: 2m 7s	remaining: 44.8s
# 74:	learn: 0.0146290	total: 2m 9s	remaining: 43.1s
# 75:	learn: 0.0143263	total: 2m 11s	remaining: 41.4s
# 76:	learn: 0.0140796	total: 2m 12s	remaining: 39.6s
# 77:	learn: 0.0138535	total: 2m 14s	remaining: 37.9s
# 78:	learn: 0.0135260	total: 2m 16s	remaining: 36.2s
# 79:	learn: 0.0132694	total: 2m 17s	remaining: 34.4s
# 80:	learn: 0.0130203	total: 2m 19s	remaining: 32.7s
# 81:	learn: 0.0128074	total: 2m 20s	remaining: 30.9s
# 82:	learn: 0.0126095	total: 2m 22s	remaining: 29.2s
# 83:	learn: 0.0122572	total: 2m 24s	remaining: 27.5s
# 84:	learn: 0.0120082	total: 2m 26s	remaining: 25.8s
# 85:	learn: 0.0116997	total: 2m 27s	remaining: 24.1s
# 86:	learn: 0.0115175	total: 2m 29s	remaining: 22.3s
# 87:	learn: 0.0111465	total: 2m 31s	remaining: 20.6s
# 88:	learn: 0.0109969	total: 2m 32s	remaining: 18.9s
# 89:	learn: 0.0107946	total: 2m 34s	remaining: 17.2s
# 90:	learn: 0.0104910	total: 2m 36s	remaining: 15.4s
# 91:	learn: 0.0102958	total: 2m 37s	remaining: 13.7s
# 92:	learn: 0.0100551	total: 2m 39s	remaining: 12s
# 93:	learn: 0.0099193	total: 2m 41s	remaining: 10.3s
# 94:	learn: 0.0097318	total: 2m 43s	remaining: 8.58s
# 95:	learn: 0.0095511	total: 2m 44s	remaining: 6.87s
# 96:	learn: 0.0093630	total: 2m 46s	remaining: 5.15s
# 97:	learn: 0.0092142	total: 2m 48s	remaining: 3.43s
# 98:	learn: 0.0090869	total: 2m 49s	remaining: 1.71s
# 99:	learn: 0.0089651	total: 2m 51s	remaining: 0us
# 0:	learn: 0.5952765	total: 1.58s	remaining: 2m 36s
# 1:	learn: 0.5112348	total: 3.25s	remaining: 2m 39s
# 2:	learn: 0.4485929	total: 4.99s	remaining: 2m 41s
# 3:	learn: 0.3922028	total: 6.79s	remaining: 2m 43s
# 4:	learn: 0.3398856	total: 8.44s	remaining: 2m 40s
# 5:	learn: 0.3069348	total: 10.1s	remaining: 2m 37s
# 6:	learn: 0.2707171	total: 11.7s	remaining: 2m 35s
# 7:	learn: 0.2417410	total: 13.4s	remaining: 2m 34s
# 8:	learn: 0.2165366	total: 15.1s	remaining: 2m 32s
# 9:	learn: 0.1950335	total: 16.7s	remaining: 2m 30s
# 10:	learn: 0.1768230	total: 18.3s	remaining: 2m 28s
# 11:	learn: 0.1610709	total: 20s	remaining: 2m 26s
# 12:	learn: 0.1471189	total: 21.8s	remaining: 2m 25s
# 13:	learn: 0.1366371	total: 23.6s	remaining: 2m 24s
# 14:	learn: 0.1266417	total: 25.2s	remaining: 2m 22s
# 15:	learn: 0.1181350	total: 26.9s	remaining: 2m 20s
# 16:	learn: 0.1101687	total: 28.5s	remaining: 2m 19s
# 17:	learn: 0.1025964	total: 30.2s	remaining: 2m 17s
# 18:	learn: 0.0963940	total: 31.8s	remaining: 2m 15s
# 19:	learn: 0.0908471	total: 33.5s	remaining: 2m 13s
# 20:	learn: 0.0849121	total: 35.2s	remaining: 2m 12s
# 21:	learn: 0.0803328	total: 36.9s	remaining: 2m 10s
# 22:	learn: 0.0753601	total: 38.7s	remaining: 2m 9s
# 23:	learn: 0.0710982	total: 40.3s	remaining: 2m 7s
# 24:	learn: 0.0677472	total: 42s	remaining: 2m 6s
# 25:	learn: 0.0639668	total: 43.7s	remaining: 2m 4s
# 26:	learn: 0.0612601	total: 45.3s	remaining: 2m 2s
# 27:	learn: 0.0586781	total: 46.9s	remaining: 2m
# 28:	learn: 0.0561585	total: 48.6s	remaining: 1m 58s
# 29:	learn: 0.0528428	total: 50.2s	remaining: 1m 57s
# 30:	learn: 0.0507388	total: 51.9s	remaining: 1m 55s
# 31:	learn: 0.0486712	total: 53.7s	remaining: 1m 54s
# 32:	learn: 0.0464417	total: 55.4s	remaining: 1m 52s
# 33:	learn: 0.0447146	total: 57.1s	remaining: 1m 50s
# 34:	learn: 0.0429199	total: 58.7s	remaining: 1m 49s
# 35:	learn: 0.0411177	total: 1m	remaining: 1m 47s
# 36:	learn: 0.0396094	total: 1m 2s	remaining: 1m 45s
# 37:	learn: 0.0383177	total: 1m 3s	remaining: 1m 43s
# 38:	learn: 0.0372000	total: 1m 5s	remaining: 1m 42s
# 39:	learn: 0.0357598	total: 1m 7s	remaining: 1m 40s
# 40:	learn: 0.0345285	total: 1m 8s	remaining: 1m 38s
# 41:	learn: 0.0331694	total: 1m 10s	remaining: 1m 37s
# 42:	learn: 0.0318555	total: 1m 12s	remaining: 1m 35s
# 43:	learn: 0.0309503	total: 1m 13s	remaining: 1m 34s
# 44:	learn: 0.0299827	total: 1m 15s	remaining: 1m 32s
# 45:	learn: 0.0291654	total: 1m 17s	remaining: 1m 30s
# 46:	learn: 0.0284468	total: 1m 18s	remaining: 1m 28s
# 47:	learn: 0.0276264	total: 1m 20s	remaining: 1m 27s
# 48:	learn: 0.0267940	total: 1m 22s	remaining: 1m 25s
# 49:	learn: 0.0260539	total: 1m 23s	remaining: 1m 23s
# 50:	learn: 0.0253451	total: 1m 25s	remaining: 1m 22s
# 51:	learn: 0.0247245	total: 1m 27s	remaining: 1m 20s
# 52:	learn: 0.0241635	total: 1m 29s	remaining: 1m 18s
# 53:	learn: 0.0236203	total: 1m 30s	remaining: 1m 17s
# 54:	learn: 0.0229692	total: 1m 32s	remaining: 1m 15s
# 55:	learn: 0.0224384	total: 1m 34s	remaining: 1m 13s
# 56:	learn: 0.0217809	total: 1m 35s	remaining: 1m 12s
# 57:	learn: 0.0213165	total: 1m 37s	remaining: 1m 10s
# 58:	learn: 0.0206101	total: 1m 39s	remaining: 1m 8s
# 59:	learn: 0.0202522	total: 1m 40s	remaining: 1m 7s
# 60:	learn: 0.0197823	total: 1m 42s	remaining: 1m 5s
# 61:	learn: 0.0193764	total: 1m 44s	remaining: 1m 3s
# 62:	learn: 0.0190412	total: 1m 46s	remaining: 1m 2s
# 63:	learn: 0.0186411	total: 1m 47s	remaining: 1m
# 64:	learn: 0.0182546	total: 1m 49s	remaining: 58.9s
# 65:	learn: 0.0178427	total: 1m 51s	remaining: 57.2s
# 66:	learn: 0.0173787	total: 1m 52s	remaining: 55.5s
# 67:	learn: 0.0169827	total: 1m 54s	remaining: 53.8s
# 68:	learn: 0.0167045	total: 1m 56s	remaining: 52.1s
# 69:	learn: 0.0163440	total: 1m 57s	remaining: 50.5s
# 70:	learn: 0.0160369	total: 1m 59s	remaining: 48.8s
# 71:	learn: 0.0157464	total: 2m 1s	remaining: 47.2s
# 72:	learn: 0.0153521	total: 2m 2s	remaining: 45.5s
# 73:	learn: 0.0150934	total: 2m 4s	remaining: 43.8s
# 74:	learn: 0.0147577	total: 2m 6s	remaining: 42.1s
# 75:	learn: 0.0144730	total: 2m 7s	remaining: 40.4s
# 76:	learn: 0.0142295	total: 2m 9s	remaining: 38.7s
# 77:	learn: 0.0139996	total: 2m 11s	remaining: 37s
# 78:	learn: 0.0137268	total: 2m 12s	remaining: 35.3s
# 79:	learn: 0.0134512	total: 2m 14s	remaining: 33.7s
# 80:	learn: 0.0132210	total: 2m 16s	remaining: 32s
# 81:	learn: 0.0130311	total: 2m 18s	remaining: 30.3s
# 82:	learn: 0.0127509	total: 2m 19s	remaining: 28.6s
# 83:	learn: 0.0124605	total: 2m 21s	remaining: 26.9s
# 84:	learn: 0.0119959	total: 2m 23s	remaining: 25.2s
# 85:	learn: 0.0116834	total: 2m 24s	remaining: 23.6s
# 86:	learn: 0.0114936	total: 2m 26s	remaining: 21.9s
# 87:	learn: 0.0112864	total: 2m 28s	remaining: 20.2s
# 88:	learn: 0.0110808	total: 2m 29s	remaining: 18.5s
# 89:	learn: 0.0108352	total: 2m 31s	remaining: 16.8s
# 90:	learn: 0.0106494	total: 2m 33s	remaining: 15.2s
# 91:	learn: 0.0104694	total: 2m 34s	remaining: 13.5s
# 92:	learn: 0.0103058	total: 2m 36s	remaining: 11.8s
# 93:	learn: 0.0101391	total: 2m 38s	remaining: 10.1s
# 94:	learn: 0.0099785	total: 2m 39s	remaining: 8.41s
# 95:	learn: 0.0096689	total: 2m 41s	remaining: 6.73s
# 96:	learn: 0.0095043	total: 2m 43s	remaining: 5.05s
# 97:	learn: 0.0093130	total: 2m 45s	remaining: 3.37s
# 98:	learn: 0.0091722	total: 2m 46s	remaining: 1.68s
# 99:	learn: 0.0088824	total: 2m 48s	remaining: 0us
# 0:	learn: 0.5977079	total: 1.62s	remaining: 2m 40s
# 1:	learn: 0.5151022	total: 3.35s	remaining: 2m 44s
# 2:	learn: 0.4507416	total: 5.05s	remaining: 2m 43s
# 3:	learn: 0.3945583	total: 6.7s	remaining: 2m 40s
# 4:	learn: 0.3449086	total: 8.39s	remaining: 2m 39s
# 5:	learn: 0.3069524	total: 10.1s	remaining: 2m 38s
# 6:	learn: 0.2712225	total: 11.9s	remaining: 2m 37s
# 7:	learn: 0.2446897	total: 13.6s	remaining: 2m 36s
# 8:	learn: 0.2204796	total: 15.3s	remaining: 2m 35s
# 9:	learn: 0.1999891	total: 17s	remaining: 2m 32s
# 10:	learn: 0.1821906	total: 18.7s	remaining: 2m 30s
# 11:	learn: 0.1645822	total: 20.3s	remaining: 2m 29s
# 12:	learn: 0.1514621	total: 22s	remaining: 2m 27s
# 13:	learn: 0.1376318	total: 23.7s	remaining: 2m 25s
# 14:	learn: 0.1269554	total: 25.4s	remaining: 2m 23s
# 15:	learn: 0.1178059	total: 27.1s	remaining: 2m 22s
# 16:	learn: 0.1084573	total: 28.9s	remaining: 2m 20s
# 17:	learn: 0.1015284	total: 30.7s	remaining: 2m 19s
# 18:	learn: 0.0949724	total: 32.4s	remaining: 2m 18s
# 19:	learn: 0.0878059	total: 34.1s	remaining: 2m 16s
# 20:	learn: 0.0829112	total: 35.8s	remaining: 2m 14s
# 21:	learn: 0.0779614	total: 37.4s	remaining: 2m 12s
# 22:	learn: 0.0734076	total: 39.1s	remaining: 2m 10s
# 23:	learn: 0.0690453	total: 40.7s	remaining: 2m 8s
# 24:	learn: 0.0657529	total: 42.4s	remaining: 2m 7s
# 25:	learn: 0.0621223	total: 44.1s	remaining: 2m 5s
# 26:	learn: 0.0597216	total: 45.8s	remaining: 2m 3s
# 27:	learn: 0.0569850	total: 47.5s	remaining: 2m 2s
# 28:	learn: 0.0541493	total: 49.2s	remaining: 2m
# 29:	learn: 0.0511634	total: 50.9s	remaining: 1m 58s
# 30:	learn: 0.0490630	total: 52.5s	remaining: 1m 56s
# 31:	learn: 0.0468099	total: 54.2s	remaining: 1m 55s
# 32:	learn: 0.0451365	total: 55.9s	remaining: 1m 53s
# 33:	learn: 0.0435104	total: 57.5s	remaining: 1m 51s
# 34:	learn: 0.0415138	total: 59.2s	remaining: 1m 49s
# 35:	learn: 0.0401773	total: 1m 1s	remaining: 1m 48s
# 36:	learn: 0.0388174	total: 1m 2s	remaining: 1m 47s
# 37:	learn: 0.0375440	total: 1m 4s	remaining: 1m 45s
# 38:	learn: 0.0364252	total: 1m 6s	remaining: 1m 43s
# 39:	learn: 0.0351244	total: 1m 7s	remaining: 1m 41s
# 40:	learn: 0.0338376	total: 1m 9s	remaining: 1m 40s
# 41:	learn: 0.0325125	total: 1m 11s	remaining: 1m 38s
# 42:	learn: 0.0308465	total: 1m 13s	remaining: 1m 36s
# 43:	learn: 0.0299719	total: 1m 14s	remaining: 1m 35s
# 44:	learn: 0.0289077	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0280137	total: 1m 18s	remaining: 1m 31s
# 46:	learn: 0.0273295	total: 1m 19s	remaining: 1m 30s
# 47:	learn: 0.0265889	total: 1m 21s	remaining: 1m 28s
# 48:	learn: 0.0258035	total: 1m 23s	remaining: 1m 26s
# 49:	learn: 0.0252303	total: 1m 24s	remaining: 1m 24s
# 50:	learn: 0.0246877	total: 1m 26s	remaining: 1m 23s
# 51:	learn: 0.0241034	total: 1m 28s	remaining: 1m 21s
# 52:	learn: 0.0235508	total: 1m 29s	remaining: 1m 19s
# 53:	learn: 0.0229241	total: 1m 31s	remaining: 1m 17s
# 54:	learn: 0.0223165	total: 1m 33s	remaining: 1m 16s
# 55:	learn: 0.0218001	total: 1m 35s	remaining: 1m 14s
# 56:	learn: 0.0213524	total: 1m 36s	remaining: 1m 12s
# 57:	learn: 0.0209184	total: 1m 38s	remaining: 1m 11s
# 58:	learn: 0.0204528	total: 1m 39s	remaining: 1m 9s
# 59:	learn: 0.0199155	total: 1m 41s	remaining: 1m 7s
# 60:	learn: 0.0194062	total: 1m 43s	remaining: 1m 6s
# 61:	learn: 0.0189972	total: 1m 44s	remaining: 1m 4s
# 62:	learn: 0.0186272	total: 1m 46s	remaining: 1m 2s
# 63:	learn: 0.0182347	total: 1m 48s	remaining: 1m
# 64:	learn: 0.0179037	total: 1m 50s	remaining: 59.3s
# 65:	learn: 0.0175550	total: 1m 51s	remaining: 57.6s
# 66:	learn: 0.0171845	total: 1m 53s	remaining: 55.9s
# 67:	learn: 0.0167985	total: 1m 55s	remaining: 54.2s
# 68:	learn: 0.0164123	total: 1m 56s	remaining: 52.5s
# 69:	learn: 0.0161378	total: 1m 58s	remaining: 50.8s
# 70:	learn: 0.0158348	total: 2m	remaining: 49.1s
# 71:	learn: 0.0155671	total: 2m 1s	remaining: 47.4s
# 72:	learn: 0.0152511	total: 2m 3s	remaining: 45.7s
# 73:	learn: 0.0149098	total: 2m 5s	remaining: 44s
# 74:	learn: 0.0145999	total: 2m 6s	remaining: 42.3s
# 75:	learn: 0.0143346	total: 2m 8s	remaining: 40.6s
# 76:	learn: 0.0140880	total: 2m 10s	remaining: 38.9s
# 77:	learn: 0.0138336	total: 2m 11s	remaining: 37.2s
# 78:	learn: 0.0135976	total: 2m 13s	remaining: 35.5s
# 79:	learn: 0.0133746	total: 2m 15s	remaining: 33.8s
# 80:	learn: 0.0131504	total: 2m 16s	remaining: 32.1s
# 81:	learn: 0.0129522	total: 2m 18s	remaining: 30.4s
# 82:	learn: 0.0126908	total: 2m 20s	remaining: 28.7s
# 83:	learn: 0.0124278	total: 2m 22s	remaining: 27.1s
# 84:	learn: 0.0121763	total: 2m 23s	remaining: 25.4s
# 85:	learn: 0.0119273	total: 2m 25s	remaining: 23.7s
# 86:	learn: 0.0117017	total: 2m 27s	remaining: 22s
# 87:	learn: 0.0114956	total: 2m 28s	remaining: 20.3s
# 88:	learn: 0.0112400	total: 2m 30s	remaining: 18.6s
# 89:	learn: 0.0109243	total: 2m 31s	remaining: 16.9s
# 90:	learn: 0.0107260	total: 2m 33s	remaining: 15.2s
# 91:	learn: 0.0105293	total: 2m 35s	remaining: 13.5s
# 92:	learn: 0.0103636	total: 2m 37s	remaining: 11.8s
# 93:	learn: 0.0101923	total: 2m 38s	remaining: 10.1s
# 94:	learn: 0.0099218	total: 2m 40s	remaining: 8.45s
# 95:	learn: 0.0096872	total: 2m 42s	remaining: 6.76s
# 96:	learn: 0.0095387	total: 2m 43s	remaining: 5.07s
# 97:	learn: 0.0093675	total: 2m 45s	remaining: 3.38s
# 98:	learn: 0.0091858	total: 2m 47s	remaining: 1.69s
# 99:	learn: 0.0090005	total: 2m 48s	remaining: 0us
# 0:	learn: 0.5921467	total: 1.57s	remaining: 2m 35s
# 1:	learn: 0.5086312	total: 3.33s	remaining: 2m 43s
# 2:	learn: 0.4420723	total: 5.09s	remaining: 2m 44s
# 3:	learn: 0.3848912	total: 6.78s	remaining: 2m 42s
# 4:	learn: 0.3396577	total: 8.43s	remaining: 2m 40s
# 5:	learn: 0.3025343	total: 10.1s	remaining: 2m 38s
# 6:	learn: 0.2691521	total: 11.8s	remaining: 2m 36s
# 7:	learn: 0.2433051	total: 13.4s	remaining: 2m 34s
# 8:	learn: 0.2191991	total: 15.1s	remaining: 2m 32s
# 9:	learn: 0.1968125	total: 16.7s	remaining: 2m 30s
# 10:	learn: 0.1787652	total: 18.4s	remaining: 2m 29s
# 11:	learn: 0.1635506	total: 20.2s	remaining: 2m 28s
# 12:	learn: 0.1517215	total: 22s	remaining: 2m 26s
# 13:	learn: 0.1410488	total: 23.6s	remaining: 2m 25s
# 14:	learn: 0.1294869	total: 25.3s	remaining: 2m 23s
# 15:	learn: 0.1187407	total: 26.9s	remaining: 2m 21s
# 16:	learn: 0.1111229	total: 28.6s	remaining: 2m 19s
# 17:	learn: 0.1031334	total: 30.2s	remaining: 2m 17s
# 18:	learn: 0.0965744	total: 31.9s	remaining: 2m 15s
# 19:	learn: 0.0895107	total: 33.5s	remaining: 2m 14s
# 20:	learn: 0.0837677	total: 35.3s	remaining: 2m 12s
# 21:	learn: 0.0789809	total: 37.1s	remaining: 2m 11s
# 22:	learn: 0.0749458	total: 38.7s	remaining: 2m 9s
# 23:	learn: 0.0713666	total: 40.4s	remaining: 2m 7s
# 24:	learn: 0.0678708	total: 42.1s	remaining: 2m 6s
# 25:	learn: 0.0644711	total: 43.7s	remaining: 2m 4s
# 26:	learn: 0.0616477	total: 45.4s	remaining: 2m 2s
# 27:	learn: 0.0590481	total: 47.1s	remaining: 2m 1s
# 28:	learn: 0.0561035	total: 48.7s	remaining: 1m 59s
# 29:	learn: 0.0528537	total: 50.5s	remaining: 1m 57s
# 30:	learn: 0.0508747	total: 52.3s	remaining: 1m 56s
# 31:	learn: 0.0488710	total: 54.1s	remaining: 1m 54s
# 32:	learn: 0.0469267	total: 55.7s	remaining: 1m 53s
# 33:	learn: 0.0452060	total: 57.4s	remaining: 1m 51s
# 34:	learn: 0.0431117	total: 59.1s	remaining: 1m 49s
# 35:	learn: 0.0414931	total: 1m	remaining: 1m 48s
# 36:	learn: 0.0399123	total: 1m 2s	remaining: 1m 46s
# 37:	learn: 0.0385320	total: 1m 4s	remaining: 1m 44s
# 38:	learn: 0.0374835	total: 1m 5s	remaining: 1m 43s
# 39:	learn: 0.0361150	total: 1m 7s	remaining: 1m 41s
# 40:	learn: 0.0347713	total: 1m 9s	remaining: 1m 39s
# 41:	learn: 0.0335909	total: 1m 11s	remaining: 1m 38s
# 42:	learn: 0.0323791	total: 1m 12s	remaining: 1m 36s
# 43:	learn: 0.0312035	total: 1m 14s	remaining: 1m 34s
# 44:	learn: 0.0300835	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0291724	total: 1m 17s	remaining: 1m 31s
# 46:	learn: 0.0283832	total: 1m 19s	remaining: 1m 29s
# 47:	learn: 0.0276587	total: 1m 21s	remaining: 1m 27s
# 48:	learn: 0.0269408	total: 1m 22s	remaining: 1m 26s
# 49:	learn: 0.0262858	total: 1m 24s	remaining: 1m 24s
# 50:	learn: 0.0256125	total: 1m 26s	remaining: 1m 22s
# 51:	learn: 0.0248566	total: 1m 27s	remaining: 1m 21s
# 52:	learn: 0.0243247	total: 1m 29s	remaining: 1m 19s
# 53:	learn: 0.0237497	total: 1m 31s	remaining: 1m 17s
# 54:	learn: 0.0229743	total: 1m 32s	remaining: 1m 16s
# 55:	learn: 0.0222513	total: 1m 34s	remaining: 1m 14s
# 56:	learn: 0.0218497	total: 1m 36s	remaining: 1m 12s
# 57:	learn: 0.0213926	total: 1m 37s	remaining: 1m 10s
# 58:	learn: 0.0208277	total: 1m 39s	remaining: 1m 9s
# 59:	learn: 0.0203650	total: 1m 41s	remaining: 1m 7s
# 60:	learn: 0.0198211	total: 1m 43s	remaining: 1m 5s
# 61:	learn: 0.0193687	total: 1m 44s	remaining: 1m 4s
# 62:	learn: 0.0189559	total: 1m 46s	remaining: 1m 2s
# 63:	learn: 0.0186277	total: 1m 48s	remaining: 1m
# 64:	learn: 0.0182882	total: 1m 49s	remaining: 59.1s
# 65:	learn: 0.0178676	total: 1m 51s	remaining: 57.4s
# 66:	learn: 0.0174755	total: 1m 53s	remaining: 55.7s
# 67:	learn: 0.0171926	total: 1m 54s	remaining: 54.1s
# 68:	learn: 0.0168217	total: 1m 56s	remaining: 52.4s
# 69:	learn: 0.0165005	total: 1m 58s	remaining: 50.8s
# 70:	learn: 0.0162503	total: 2m	remaining: 49.1s
# 71:	learn: 0.0159664	total: 2m 1s	remaining: 47.4s
# 72:	learn: 0.0155801	total: 2m 3s	remaining: 45.7s
# 73:	learn: 0.0152845	total: 2m 5s	remaining: 44s
# 74:	learn: 0.0149857	total: 2m 6s	remaining: 42.3s
# 75:	learn: 0.0147110	total: 2m 8s	remaining: 40.6s
# 76:	learn: 0.0144476	total: 2m 10s	remaining: 38.9s
# 77:	learn: 0.0140873	total: 2m 12s	remaining: 37.2s
# 78:	learn: 0.0137381	total: 2m 13s	remaining: 35.6s
# 79:	learn: 0.0134603	total: 2m 15s	remaining: 33.9s
# 80:	learn: 0.0132238	total: 2m 17s	remaining: 32.2s
# 81:	learn: 0.0129938	total: 2m 18s	remaining: 30.5s
# 82:	learn: 0.0127742	total: 2m 20s	remaining: 28.8s
# 83:	learn: 0.0124604	total: 2m 22s	remaining: 27.1s
# 84:	learn: 0.0122091	total: 2m 23s	remaining: 25.4s
# 85:	learn: 0.0119861	total: 2m 25s	remaining: 23.7s
# 86:	learn: 0.0115909	total: 2m 27s	remaining: 22s
# 87:	learn: 0.0114016	total: 2m 28s	remaining: 20.3s
# 88:	learn: 0.0112106	total: 2m 30s	remaining: 18.6s
# 89:	learn: 0.0109404	total: 2m 32s	remaining: 16.9s
# 90:	learn: 0.0108084	total: 2m 34s	remaining: 15.2s
# 91:	learn: 0.0106461	total: 2m 35s	remaining: 13.5s
# 92:	learn: 0.0104301	total: 2m 37s	remaining: 11.8s
# 93:	learn: 0.0102348	total: 2m 38s	remaining: 10.1s
# 94:	learn: 0.0100767	total: 2m 40s	remaining: 8.46s
# 95:	learn: 0.0098074	total: 2m 42s	remaining: 6.76s
# 96:	learn: 0.0096389	total: 2m 44s	remaining: 5.08s
# 97:	learn: 0.0094971	total: 2m 45s	remaining: 3.38s
# 98:	learn: 0.0093256	total: 2m 47s	remaining: 1.69s
# 99:	learn: 0.0091762	total: 2m 49s	remaining: 0us
# 0:	learn: 0.5052004	total: 1.57s	remaining: 2m 35s
# 1:	learn: 0.3821894	total: 3.28s	remaining: 2m 40s
# 2:	learn: 0.2969769	total: 4.99s	remaining: 2m 41s
# 3:	learn: 0.2348406	total: 6.72s	remaining: 2m 41s
# 4:	learn: 0.1932891	total: 8.44s	remaining: 2m 40s
# 5:	learn: 0.1596532	total: 10.2s	remaining: 2m 40s
# 6:	learn: 0.1330706	total: 12s	remaining: 2m 39s
# 7:	learn: 0.1140766	total: 13.6s	remaining: 2m 36s
# 8:	learn: 0.0982808	total: 15.3s	remaining: 2m 35s
# 9:	learn: 0.0864745	total: 17s	remaining: 2m 33s
# 10:	learn: 0.0758438	total: 18.7s	remaining: 2m 31s
# 11:	learn: 0.0681040	total: 20.4s	remaining: 2m 29s
# 12:	learn: 0.0623480	total: 22.1s	remaining: 2m 27s
# 13:	learn: 0.0562093	total: 23.7s	remaining: 2m 25s
# 14:	learn: 0.0507463	total: 25.5s	remaining: 2m 24s
# 15:	learn: 0.0461528	total: 27.3s	remaining: 2m 23s
# 16:	learn: 0.0425866	total: 29s	remaining: 2m 21s
# 17:	learn: 0.0389615	total: 30.7s	remaining: 2m 19s
# 18:	learn: 0.0366240	total: 32.3s	remaining: 2m 17s
# 19:	learn: 0.0339494	total: 34s	remaining: 2m 15s
# 20:	learn: 0.0318596	total: 35.6s	remaining: 2m 14s
# 21:	learn: 0.0298425	total: 37.3s	remaining: 2m 12s
# 22:	learn: 0.0282781	total: 39s	remaining: 2m 10s
# 23:	learn: 0.0263997	total: 40.7s	remaining: 2m 8s
# 24:	learn: 0.0252591	total: 42.5s	remaining: 2m 7s
# 25:	learn: 0.0239815	total: 44.2s	remaining: 2m 5s
# 26:	learn: 0.0229642	total: 46s	remaining: 2m 4s
# 27:	learn: 0.0219853	total: 47.7s	remaining: 2m 2s
# 28:	learn: 0.0203302	total: 49.4s	remaining: 2m
# 29:	learn: 0.0192358	total: 51.1s	remaining: 1m 59s
# 30:	learn: 0.0186571	total: 52.8s	remaining: 1m 57s
# 31:	learn: 0.0179818	total: 54.5s	remaining: 1m 55s
# 32:	learn: 0.0172536	total: 56.2s	remaining: 1m 54s
# 33:	learn: 0.0165740	total: 58s	remaining: 1m 52s
# 34:	learn: 0.0160357	total: 59.7s	remaining: 1m 50s
# 35:	learn: 0.0153650	total: 1m 1s	remaining: 1m 49s
# 36:	learn: 0.0147632	total: 1m 3s	remaining: 1m 47s
# 37:	learn: 0.0142695	total: 1m 4s	remaining: 1m 45s
# 38:	learn: 0.0136215	total: 1m 6s	remaining: 1m 43s
# 39:	learn: 0.0132151	total: 1m 8s	remaining: 1m 42s
# 40:	learn: 0.0126154	total: 1m 9s	remaining: 1m 40s
# 41:	learn: 0.0118352	total: 1m 11s	remaining: 1m 38s
# 42:	learn: 0.0113741	total: 1m 13s	remaining: 1m 37s
# 43:	learn: 0.0110495	total: 1m 15s	remaining: 1m 35s
# 44:	learn: 0.0106002	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0101501	total: 1m 18s	remaining: 1m 32s
# 46:	learn: 0.0093555	total: 1m 20s	remaining: 1m 30s
# 47:	learn: 0.0090226	total: 1m 21s	remaining: 1m 28s
# 48:	learn: 0.0087482	total: 1m 23s	remaining: 1m 26s
# 49:	learn: 0.0085123	total: 1m 25s	remaining: 1m 25s
# 50:	learn: 0.0082075	total: 1m 26s	remaining: 1m 23s
# 51:	learn: 0.0080131	total: 1m 28s	remaining: 1m 21s
# 52:	learn: 0.0077647	total: 1m 30s	remaining: 1m 19s
# 53:	learn: 0.0075461	total: 1m 31s	remaining: 1m 18s
# 54:	learn: 0.0073111	total: 1m 33s	remaining: 1m 16s
# 55:	learn: 0.0071526	total: 1m 35s	remaining: 1m 14s
# 56:	learn: 0.0068895	total: 1m 36s	remaining: 1m 13s
# 57:	learn: 0.0066855	total: 1m 38s	remaining: 1m 11s
# 58:	learn: 0.0065127	total: 1m 40s	remaining: 1m 9s
# 59:	learn: 0.0063823	total: 1m 41s	remaining: 1m 7s
# 60:	learn: 0.0062557	total: 1m 43s	remaining: 1m 6s
# 61:	learn: 0.0061361	total: 1m 45s	remaining: 1m 4s
# 62:	learn: 0.0059992	total: 1m 47s	remaining: 1m 2s
# 63:	learn: 0.0059042	total: 1m 48s	remaining: 1m 1s
# 64:	learn: 0.0057360	total: 1m 50s	remaining: 59.5s
# 65:	learn: 0.0056223	total: 1m 52s	remaining: 57.8s
# 66:	learn: 0.0054162	total: 1m 53s	remaining: 56.1s
# 67:	learn: 0.0052979	total: 1m 55s	remaining: 54.4s
# 68:	learn: 0.0051945	total: 1m 57s	remaining: 52.7s
# 69:	learn: 0.0050588	total: 1m 58s	remaining: 51s
# 70:	learn: 0.0049623	total: 2m	remaining: 49.2s
# 71:	learn: 0.0048714	total: 2m 2s	remaining: 47.6s
# 72:	learn: 0.0047937	total: 2m 4s	remaining: 45.9s
# 73:	learn: 0.0046578	total: 2m 5s	remaining: 44.2s
# 74:	learn: 0.0045375	total: 2m 7s	remaining: 42.5s
# 75:	learn: 0.0044801	total: 2m 9s	remaining: 40.7s
# 76:	learn: 0.0043751	total: 2m 10s	remaining: 39s
# 77:	learn: 0.0043062	total: 2m 12s	remaining: 37.3s
# 78:	learn: 0.0042475	total: 2m 13s	remaining: 35.6s
# 79:	learn: 0.0041899	total: 2m 15s	remaining: 33.9s
# 80:	learn: 0.0041362	total: 2m 17s	remaining: 32.2s
# 81:	learn: 0.0040495	total: 2m 19s	remaining: 30.5s
# 82:	learn: 0.0039911	total: 2m 20s	remaining: 28.8s
# 83:	learn: 0.0039407	total: 2m 22s	remaining: 27.1s
# 84:	learn: 0.0037601	total: 2m 24s	remaining: 25.4s
# 85:	learn: 0.0037134	total: 2m 25s	remaining: 23.8s
# 86:	learn: 0.0036482	total: 2m 27s	remaining: 22.1s
# 87:	learn: 0.0035943	total: 2m 29s	remaining: 20.4s
# 88:	learn: 0.0035584	total: 2m 30s	remaining: 18.7s
# 89:	learn: 0.0033768	total: 2m 32s	remaining: 17s
# 90:	learn: 0.0033283	total: 2m 34s	remaining: 15.3s
# 91:	learn: 0.0031608	total: 2m 36s	remaining: 13.6s
# 92:	learn: 0.0031136	total: 2m 37s	remaining: 11.9s
# 93:	learn: 0.0030866	total: 2m 39s	remaining: 10.2s
# 94:	learn: 0.0030584	total: 2m 41s	remaining: 8.48s
# 95:	learn: 0.0030310	total: 2m 42s	remaining: 6.78s
# 96:	learn: 0.0029943	total: 2m 44s	remaining: 5.09s
# 97:	learn: 0.0029661	total: 2m 46s	remaining: 3.39s
# 98:	learn: 0.0029385	total: 2m 47s	remaining: 1.7s
# 99:	learn: 0.0028961	total: 2m 49s	remaining: 0us
# 0:	learn: 0.4924348	total: 1.72s	remaining: 2m 49s
# 1:	learn: 0.3729769	total: 3.41s	remaining: 2m 46s
# 2:	learn: 0.2934429	total: 5.05s	remaining: 2m 43s
# 3:	learn: 0.2342241	total: 6.75s	remaining: 2m 41s
# 4:	learn: 0.1840785	total: 8.46s	remaining: 2m 40s
# 5:	learn: 0.1525895	total: 10.2s	remaining: 2m 39s
# 6:	learn: 0.1281020	total: 11.9s	remaining: 2m 38s
# 7:	learn: 0.1107872	total: 13.6s	remaining: 2m 36s
# 8:	learn: 0.0959036	total: 15.3s	remaining: 2m 34s
# 9:	learn: 0.0843327	total: 17.1s	remaining: 2m 33s
# 10:	learn: 0.0750868	total: 18.9s	remaining: 2m 32s
# 11:	learn: 0.0668442	total: 20.6s	remaining: 2m 30s
# 12:	learn: 0.0601762	total: 22.3s	remaining: 2m 29s
# 13:	learn: 0.0546400	total: 24s	remaining: 2m 27s
# 14:	learn: 0.0497683	total: 25.7s	remaining: 2m 25s
# 15:	learn: 0.0455736	total: 27.4s	remaining: 2m 23s
# 16:	learn: 0.0420382	total: 29.1s	remaining: 2m 22s
# 17:	learn: 0.0390434	total: 30.9s	remaining: 2m 20s
# 18:	learn: 0.0364183	total: 32.6s	remaining: 2m 19s
# 19:	learn: 0.0337010	total: 34.4s	remaining: 2m 17s
# 20:	learn: 0.0314580	total: 36.1s	remaining: 2m 15s
# 21:	learn: 0.0293851	total: 37.8s	remaining: 2m 13s
# 22:	learn: 0.0274090	total: 39.5s	remaining: 2m 12s
# 23:	learn: 0.0255219	total: 41.2s	remaining: 2m 10s
# 24:	learn: 0.0244695	total: 42.8s	remaining: 2m 8s
# 25:	learn: 0.0228630	total: 44.5s	remaining: 2m 6s
# 26:	learn: 0.0218420	total: 46.2s	remaining: 2m 5s
# 27:	learn: 0.0210094	total: 48s	remaining: 2m 3s
# 28:	learn: 0.0201739	total: 49.8s	remaining: 2m 1s
# 29:	learn: 0.0192440	total: 51.5s	remaining: 2m
# 30:	learn: 0.0185516	total: 53.2s	remaining: 1m 58s
# 31:	learn: 0.0178219	total: 54.9s	remaining: 1m 56s
# 32:	learn: 0.0171915	total: 56.5s	remaining: 1m 54s
# 33:	learn: 0.0165218	total: 58.2s	remaining: 1m 52s
# 34:	learn: 0.0157961	total: 59.9s	remaining: 1m 51s
# 35:	learn: 0.0151742	total: 1m 1s	remaining: 1m 49s
# 36:	learn: 0.0146497	total: 1m 3s	remaining: 1m 47s
# 37:	learn: 0.0141441	total: 1m 5s	remaining: 1m 46s
# 38:	learn: 0.0136686	total: 1m 6s	remaining: 1m 44s
# 39:	learn: 0.0131627	total: 1m 8s	remaining: 1m 42s
# 40:	learn: 0.0127250	total: 1m 10s	remaining: 1m 41s
# 41:	learn: 0.0123289	total: 1m 11s	remaining: 1m 39s
# 42:	learn: 0.0117084	total: 1m 13s	remaining: 1m 37s
# 43:	learn: 0.0111556	total: 1m 15s	remaining: 1m 35s
# 44:	learn: 0.0108208	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0104823	total: 1m 18s	remaining: 1m 32s
# 46:	learn: 0.0101434	total: 1m 20s	remaining: 1m 30s
# 47:	learn: 0.0096228	total: 1m 22s	remaining: 1m 28s
# 48:	learn: 0.0091162	total: 1m 23s	remaining: 1m 27s
# 49:	learn: 0.0087138	total: 1m 25s	remaining: 1m 25s
# 50:	learn: 0.0085032	total: 1m 27s	remaining: 1m 23s
# 51:	learn: 0.0083055	total: 1m 28s	remaining: 1m 21s
# 52:	learn: 0.0080771	total: 1m 30s	remaining: 1m 20s
# 53:	learn: 0.0078523	total: 1m 32s	remaining: 1m 18s
# 54:	learn: 0.0074715	total: 1m 33s	remaining: 1m 16s
# 55:	learn: 0.0073038	total: 1m 35s	remaining: 1m 15s
# 56:	learn: 0.0071415	total: 1m 37s	remaining: 1m 13s
# 57:	learn: 0.0069308	total: 1m 38s	remaining: 1m 11s
# 58:	learn: 0.0067203	total: 1m 40s	remaining: 1m 9s
# 59:	learn: 0.0064626	total: 1m 42s	remaining: 1m 8s
# 60:	learn: 0.0061964	total: 1m 43s	remaining: 1m 6s
# 61:	learn: 0.0059898	total: 1m 45s	remaining: 1m 4s
# 62:	learn: 0.0058214	total: 1m 47s	remaining: 1m 2s
# 63:	learn: 0.0055858	total: 1m 48s	remaining: 1m 1s
# 64:	learn: 0.0054362	total: 1m 50s	remaining: 59.5s
# 65:	learn: 0.0051430	total: 1m 52s	remaining: 57.9s
# 66:	learn: 0.0050076	total: 1m 54s	remaining: 56.2s
# 67:	learn: 0.0049059	total: 1m 55s	remaining: 54.5s
# 68:	learn: 0.0047875	total: 1m 57s	remaining: 52.8s
# 69:	learn: 0.0046401	total: 1m 59s	remaining: 51.1s
# 70:	learn: 0.0044610	total: 2m	remaining: 49.4s
# 71:	learn: 0.0043473	total: 2m 2s	remaining: 47.6s
# 72:	learn: 0.0042519	total: 2m 4s	remaining: 45.9s
# 73:	learn: 0.0041738	total: 2m 5s	remaining: 44.2s
# 74:	learn: 0.0040827	total: 2m 7s	remaining: 42.5s
# 75:	learn: 0.0039424	total: 2m 9s	remaining: 40.8s
# 76:	learn: 0.0038421	total: 2m 11s	remaining: 39.1s
# 77:	learn: 0.0037386	total: 2m 12s	remaining: 37.4s
# 78:	learn: 0.0036678	total: 2m 14s	remaining: 35.7s
# 79:	learn: 0.0036108	total: 2m 16s	remaining: 34s
# 80:	learn: 0.0035231	total: 2m 17s	remaining: 32.3s
# 81:	learn: 0.0033958	total: 2m 19s	remaining: 30.6s
# 82:	learn: 0.0033542	total: 2m 21s	remaining: 28.9s
# 83:	learn: 0.0033000	total: 2m 22s	remaining: 27.2s
# 84:	learn: 0.0032337	total: 2m 24s	remaining: 25.5s
# 85:	learn: 0.0031281	total: 2m 26s	remaining: 23.8s
# 86:	learn: 0.0030655	total: 2m 28s	remaining: 22.1s
# 87:	learn: 0.0030204	total: 2m 29s	remaining: 20.4s
# 88:	learn: 0.0029261	total: 2m 31s	remaining: 18.7s
# 89:	learn: 0.0028272	total: 2m 33s	remaining: 17s
# 90:	learn: 0.0027903	total: 2m 34s	remaining: 15.3s
# 91:	learn: 0.0027261	total: 2m 36s	remaining: 13.6s
# 92:	learn: 0.0026801	total: 2m 38s	remaining: 11.9s
# 93:	learn: 0.0026143	total: 2m 40s	remaining: 10.2s
# 94:	learn: 0.0025771	total: 2m 41s	remaining: 8.52s
# 95:	learn: 0.0025250	total: 2m 43s	remaining: 6.82s
# 96:	learn: 0.0024589	total: 2m 45s	remaining: 5.11s
# 97:	learn: 0.0024009	total: 2m 46s	remaining: 3.41s
# 98:	learn: 0.0023370	total: 2m 48s	remaining: 1.7s
# 99:	learn: 0.0023104	total: 2m 50s	remaining: 0us
# 0:	learn: 0.5107394	total: 1.6s	remaining: 2m 38s
# 1:	learn: 0.3823237	total: 3.3s	remaining: 2m 41s
# 2:	learn: 0.2949318	total: 5.05s	remaining: 2m 43s
# 3:	learn: 0.2345448	total: 6.84s	remaining: 2m 44s
# 4:	learn: 0.1923264	total: 8.57s	remaining: 2m 42s
# 5:	learn: 0.1566964	total: 10.3s	remaining: 2m 40s
# 6:	learn: 0.1344119	total: 11.9s	remaining: 2m 38s
# 7:	learn: 0.1157462	total: 13.6s	remaining: 2m 36s
# 8:	learn: 0.0993636	total: 15.3s	remaining: 2m 34s
# 9:	learn: 0.0872645	total: 17s	remaining: 2m 33s
# 10:	learn: 0.0790213	total: 18.7s	remaining: 2m 31s
# 11:	learn: 0.0711788	total: 20.4s	remaining: 2m 29s
# 12:	learn: 0.0643879	total: 22.1s	remaining: 2m 28s
# 13:	learn: 0.0586004	total: 23.9s	remaining: 2m 26s
# 14:	learn: 0.0537564	total: 25.6s	remaining: 2m 24s
# 15:	learn: 0.0494486	total: 27.3s	remaining: 2m 23s
# 16:	learn: 0.0455039	total: 29s	remaining: 2m 21s
# 17:	learn: 0.0415725	total: 30.6s	remaining: 2m 19s
# 18:	learn: 0.0385059	total: 32.3s	remaining: 2m 17s
# 19:	learn: 0.0359199	total: 34s	remaining: 2m 16s
# 20:	learn: 0.0334011	total: 35.7s	remaining: 2m 14s
# 21:	learn: 0.0311831	total: 37.4s	remaining: 2m 12s
# 22:	learn: 0.0297072	total: 39.2s	remaining: 2m 11s
# 23:	learn: 0.0274734	total: 40.9s	remaining: 2m 9s
# 24:	learn: 0.0261973	total: 42.6s	remaining: 2m 7s
# 25:	learn: 0.0245101	total: 44.3s	remaining: 2m 5s
# 26:	learn: 0.0232722	total: 45.9s	remaining: 2m 4s
# 27:	learn: 0.0222334	total: 47.6s	remaining: 2m 2s
# 28:	learn: 0.0212318	total: 49.4s	remaining: 2m
# 29:	learn: 0.0200744	total: 51s	remaining: 1m 59s
# 30:	learn: 0.0192455	total: 52.8s	remaining: 1m 57s
# 31:	learn: 0.0185007	total: 54.6s	remaining: 1m 55s
# 32:	learn: 0.0178755	total: 56.3s	remaining: 1m 54s
# 33:	learn: 0.0172919	total: 58s	remaining: 1m 52s
# 34:	learn: 0.0166528	total: 59.7s	remaining: 1m 50s
# 35:	learn: 0.0159531	total: 1m 1s	remaining: 1m 49s
# 36:	learn: 0.0151366	total: 1m 3s	remaining: 1m 47s
# 37:	learn: 0.0146785	total: 1m 4s	remaining: 1m 45s
# 38:	learn: 0.0142818	total: 1m 6s	remaining: 1m 44s
# 39:	learn: 0.0137748	total: 1m 8s	remaining: 1m 42s
# 40:	learn: 0.0129143	total: 1m 10s	remaining: 1m 40s
# 41:	learn: 0.0125279	total: 1m 11s	remaining: 1m 39s
# 42:	learn: 0.0119609	total: 1m 13s	remaining: 1m 37s
# 43:	learn: 0.0114953	total: 1m 15s	remaining: 1m 35s
# 44:	learn: 0.0111290	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0107347	total: 1m 18s	remaining: 1m 32s
# 46:	learn: 0.0102232	total: 1m 20s	remaining: 1m 30s
# 47:	learn: 0.0097775	total: 1m 21s	remaining: 1m 28s
# 48:	learn: 0.0094620	total: 1m 23s	remaining: 1m 27s
# 49:	learn: 0.0091762	total: 1m 25s	remaining: 1m 25s
# 50:	learn: 0.0088720	total: 1m 27s	remaining: 1m 23s
# 51:	learn: 0.0085900	total: 1m 28s	remaining: 1m 22s
# 52:	learn: 0.0083523	total: 1m 30s	remaining: 1m 20s
# 53:	learn: 0.0081338	total: 1m 32s	remaining: 1m 18s
# 54:	learn: 0.0078015	total: 1m 33s	remaining: 1m 16s
# 55:	learn: 0.0075354	total: 1m 35s	remaining: 1m 15s
# 56:	learn: 0.0072305	total: 1m 37s	remaining: 1m 13s
# 57:	learn: 0.0068932	total: 1m 39s	remaining: 1m 11s
# 58:	learn: 0.0067017	total: 1m 40s	remaining: 1m 10s
# 59:	learn: 0.0064018	total: 1m 42s	remaining: 1m 8s
# 60:	learn: 0.0061570	total: 1m 44s	remaining: 1m 6s
# 61:	learn: 0.0059261	total: 1m 45s	remaining: 1m 4s
# 62:	learn: 0.0057974	total: 1m 47s	remaining: 1m 3s
# 63:	learn: 0.0056548	total: 1m 49s	remaining: 1m 1s
# 64:	learn: 0.0053940	total: 1m 50s	remaining: 59.8s
# 65:	learn: 0.0052215	total: 1m 52s	remaining: 58s
# 66:	learn: 0.0050472	total: 1m 54s	remaining: 56.3s
# 67:	learn: 0.0048451	total: 1m 55s	remaining: 54.6s
# 68:	learn: 0.0046384	total: 1m 57s	remaining: 52.9s
# 69:	learn: 0.0045520	total: 1m 59s	remaining: 51.2s
# 70:	learn: 0.0044651	total: 2m 1s	remaining: 49.5s
# 71:	learn: 0.0043708	total: 2m 2s	remaining: 47.8s
# 72:	learn: 0.0042380	total: 2m 4s	remaining: 46.1s
# 73:	learn: 0.0041142	total: 2m 6s	remaining: 44.3s
# 74:	learn: 0.0040627	total: 2m 7s	remaining: 42.6s
# 75:	learn: 0.0039976	total: 2m 9s	remaining: 40.9s
# 76:	learn: 0.0038588	total: 2m 11s	remaining: 39.2s
# 77:	learn: 0.0037705	total: 2m 12s	remaining: 37.5s
# 78:	learn: 0.0037147	total: 2m 14s	remaining: 35.8s
# 79:	learn: 0.0036142	total: 2m 16s	remaining: 34.1s
# 80:	learn: 0.0035145	total: 2m 18s	remaining: 32.4s
# 81:	learn: 0.0033670	total: 2m 19s	remaining: 30.7s
# 82:	learn: 0.0033051	total: 2m 21s	remaining: 29s
# 83:	learn: 0.0032448	total: 2m 23s	remaining: 27.3s
# 84:	learn: 0.0031589	total: 2m 24s	remaining: 25.6s
# 85:	learn: 0.0030661	total: 2m 26s	remaining: 23.9s
# 86:	learn: 0.0030087	total: 2m 28s	remaining: 22.2s
# 87:	learn: 0.0029155	total: 2m 30s	remaining: 20.5s
# 88:	learn: 0.0028383	total: 2m 31s	remaining: 18.8s
# 89:	learn: 0.0027572	total: 2m 33s	remaining: 17.1s
# 90:	learn: 0.0027060	total: 2m 35s	remaining: 15.4s
# 91:	learn: 0.0026490	total: 2m 36s	remaining: 13.6s
# 92:	learn: 0.0026115	total: 2m 38s	remaining: 11.9s
# 93:	learn: 0.0025592	total: 2m 40s	remaining: 10.2s
# 94:	learn: 0.0025037	total: 2m 41s	remaining: 8.52s
# 95:	learn: 0.0024466	total: 2m 43s	remaining: 6.82s
# 96:	learn: 0.0024188	total: 2m 45s	remaining: 5.11s
# 97:	learn: 0.0023782	total: 2m 47s	remaining: 3.41s
# 98:	learn: 0.0023473	total: 2m 48s	remaining: 1.7s
# 99:	learn: 0.0023027	total: 2m 50s	remaining: 0us
# 0:	learn: 0.5155230	total: 1.64s	remaining: 2m 42s
# 1:	learn: 0.3829244	total: 3.33s	remaining: 2m 43s
# 2:	learn: 0.3042162	total: 5.03s	remaining: 2m 42s
# 3:	learn: 0.2332948	total: 6.67s	remaining: 2m 40s
# 4:	learn: 0.1912446	total: 8.3s	remaining: 2m 37s
# 5:	learn: 0.1574596	total: 10s	remaining: 2m 36s
# 6:	learn: 0.1291101	total: 11.8s	remaining: 2m 36s
# 7:	learn: 0.1104790	total: 13.5s	remaining: 2m 35s
# 8:	learn: 0.0953968	total: 15.2s	remaining: 2m 33s
# 9:	learn: 0.0844462	total: 16.9s	remaining: 2m 32s
# 10:	learn: 0.0762571	total: 18.6s	remaining: 2m 30s
# 11:	learn: 0.0682226	total: 20.3s	remaining: 2m 29s
# 12:	learn: 0.0615019	total: 22s	remaining: 2m 27s
# 13:	learn: 0.0536249	total: 23.7s	remaining: 2m 25s
# 14:	learn: 0.0487678	total: 25.4s	remaining: 2m 23s
# 15:	learn: 0.0444889	total: 27.1s	remaining: 2m 22s
# 16:	learn: 0.0414377	total: 28.8s	remaining: 2m 20s
# 17:	learn: 0.0384529	total: 30.5s	remaining: 2m 19s
# 18:	learn: 0.0357752	total: 32.2s	remaining: 2m 17s
# 19:	learn: 0.0322632	total: 33.8s	remaining: 2m 15s
# 20:	learn: 0.0302784	total: 35.5s	remaining: 2m 13s
# 21:	learn: 0.0284534	total: 37.2s	remaining: 2m 11s
# 22:	learn: 0.0270131	total: 38.8s	remaining: 2m 9s
# 23:	learn: 0.0254919	total: 40.5s	remaining: 2m 8s
# 24:	learn: 0.0240745	total: 42.2s	remaining: 2m 6s
# 25:	learn: 0.0227354	total: 43.9s	remaining: 2m 5s
# 26:	learn: 0.0217916	total: 45.6s	remaining: 2m 3s
# 27:	learn: 0.0208467	total: 47.4s	remaining: 2m 1s
# 28:	learn: 0.0198878	total: 49s	remaining: 1m 59s
# 29:	learn: 0.0189867	total: 50.7s	remaining: 1m 58s
# 30:	learn: 0.0182040	total: 52.3s	remaining: 1m 56s
# 31:	learn: 0.0174543	total: 54s	remaining: 1m 54s
# 32:	learn: 0.0167172	total: 55.7s	remaining: 1m 53s
# 33:	learn: 0.0160783	total: 57.4s	remaining: 1m 51s
# 34:	learn: 0.0149626	total: 59.2s	remaining: 1m 49s
# 35:	learn: 0.0143166	total: 1m	remaining: 1m 48s
# 36:	learn: 0.0137547	total: 1m 2s	remaining: 1m 46s
# 37:	learn: 0.0133067	total: 1m 4s	remaining: 1m 44s
# 38:	learn: 0.0128117	total: 1m 5s	remaining: 1m 43s
# 39:	learn: 0.0122674	total: 1m 7s	remaining: 1m 41s
# 40:	learn: 0.0117427	total: 1m 9s	remaining: 1m 39s
# 41:	learn: 0.0113418	total: 1m 11s	remaining: 1m 38s
# 42:	learn: 0.0108682	total: 1m 12s	remaining: 1m 36s
# 43:	learn: 0.0104963	total: 1m 14s	remaining: 1m 34s
# 44:	learn: 0.0100897	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0097490	total: 1m 17s	remaining: 1m 31s
# 46:	learn: 0.0091823	total: 1m 19s	remaining: 1m 29s
# 47:	learn: 0.0086723	total: 1m 21s	remaining: 1m 27s
# 48:	learn: 0.0084128	total: 1m 22s	remaining: 1m 26s
# 49:	learn: 0.0081781	total: 1m 24s	remaining: 1m 24s
# 50:	learn: 0.0079719	total: 1m 26s	remaining: 1m 22s
# 51:	learn: 0.0077491	total: 1m 27s	remaining: 1m 21s
# 52:	learn: 0.0075781	total: 1m 29s	remaining: 1m 19s
# 53:	learn: 0.0074108	total: 1m 31s	remaining: 1m 17s
# 54:	learn: 0.0071344	total: 1m 32s	remaining: 1m 16s
# 55:	learn: 0.0069128	total: 1m 34s	remaining: 1m 14s
# 56:	learn: 0.0066379	total: 1m 36s	remaining: 1m 12s
# 57:	learn: 0.0063802	total: 1m 37s	remaining: 1m 10s
# 58:	learn: 0.0062530	total: 1m 39s	remaining: 1m 9s
# 59:	learn: 0.0059654	total: 1m 41s	remaining: 1m 7s
# 60:	learn: 0.0058406	total: 1m 42s	remaining: 1m 5s
# 61:	learn: 0.0057429	total: 1m 44s	remaining: 1m 4s
# 62:	learn: 0.0055365	total: 1m 46s	remaining: 1m 2s
# 63:	learn: 0.0054045	total: 1m 48s	remaining: 1m
# 64:	learn: 0.0053020	total: 1m 49s	remaining: 59.1s
# 65:	learn: 0.0051271	total: 1m 51s	remaining: 57.4s
# 66:	learn: 0.0049910	total: 1m 53s	remaining: 55.7s
# 67:	learn: 0.0049017	total: 1m 54s	remaining: 54s
# 68:	learn: 0.0047987	total: 1m 56s	remaining: 52.3s
# 69:	learn: 0.0047220	total: 1m 58s	remaining: 50.6s
# 70:	learn: 0.0046531	total: 1m 59s	remaining: 49s
# 71:	learn: 0.0044995	total: 2m 1s	remaining: 47.3s
# 72:	learn: 0.0043640	total: 2m 3s	remaining: 45.6s
# 73:	learn: 0.0042709	total: 2m 4s	remaining: 43.9s
# 74:	learn: 0.0041891	total: 2m 6s	remaining: 42.2s
# 75:	learn: 0.0041100	total: 2m 8s	remaining: 40.5s
# 76:	learn: 0.0040381	total: 2m 10s	remaining: 38.9s
# 77:	learn: 0.0039329	total: 2m 11s	remaining: 37.2s
# 78:	learn: 0.0038832	total: 2m 13s	remaining: 35.5s
# 79:	learn: 0.0038208	total: 2m 15s	remaining: 33.8s
# 80:	learn: 0.0037371	total: 2m 16s	remaining: 32.1s
# 81:	learn: 0.0036016	total: 2m 18s	remaining: 30.4s
# 82:	learn: 0.0035338	total: 2m 20s	remaining: 28.7s
# 83:	learn: 0.0034545	total: 2m 22s	remaining: 27.1s
# 84:	learn: 0.0033621	total: 2m 23s	remaining: 25.4s
# 85:	learn: 0.0033044	total: 2m 25s	remaining: 23.7s
# 86:	learn: 0.0032403	total: 2m 27s	remaining: 22s
# 87:	learn: 0.0031810	total: 2m 28s	remaining: 20.3s
# 88:	learn: 0.0031090	total: 2m 30s	remaining: 18.6s
# 89:	learn: 0.0030645	total: 2m 32s	remaining: 16.9s
# 90:	learn: 0.0030147	total: 2m 33s	remaining: 15.2s
# 91:	learn: 0.0029648	total: 2m 35s	remaining: 13.5s
# 92:	learn: 0.0029201	total: 2m 37s	remaining: 11.8s
# 93:	learn: 0.0028688	total: 2m 38s	remaining: 10.1s
# 94:	learn: 0.0027532	total: 2m 40s	remaining: 8.45s
# 95:	learn: 0.0027086	total: 2m 42s	remaining: 6.76s
# 96:	learn: 0.0026668	total: 2m 43s	remaining: 5.07s
# 97:	learn: 0.0026305	total: 2m 45s	remaining: 3.38s
# 98:	learn: 0.0025459	total: 2m 47s	remaining: 1.69s
# 99:	learn: 0.0025156	total: 2m 48s	remaining: 0us
# 0:	learn: 0.5053352	total: 1.68s	remaining: 2m 46s
# 1:	learn: 0.3791981	total: 3.39s	remaining: 2m 46s
# 2:	learn: 0.2890537	total: 5.14s	remaining: 2m 46s
# 3:	learn: 0.2218012	total: 6.84s	remaining: 2m 44s
# 4:	learn: 0.1833707	total: 8.53s	remaining: 2m 42s
# 5:	learn: 0.1549679	total: 10.2s	remaining: 2m 40s
# 6:	learn: 0.1351411	total: 11.9s	remaining: 2m 37s
# 7:	learn: 0.1180405	total: 13.6s	remaining: 2m 35s
# 8:	learn: 0.1009454	total: 15.2s	remaining: 2m 34s
# 9:	learn: 0.0885849	total: 16.9s	remaining: 2m 32s
# 10:	learn: 0.0777623	total: 18.7s	remaining: 2m 31s
# 11:	learn: 0.0702740	total: 20.4s	remaining: 2m 29s
# 12:	learn: 0.0628931	total: 22.1s	remaining: 2m 27s
# 13:	learn: 0.0562336	total: 23.8s	remaining: 2m 26s
# 14:	learn: 0.0511837	total: 25.5s	remaining: 2m 24s
# 15:	learn: 0.0470441	total: 27.2s	remaining: 2m 22s
# 16:	learn: 0.0434941	total: 28.9s	remaining: 2m 21s
# 17:	learn: 0.0406222	total: 30.6s	remaining: 2m 19s
# 18:	learn: 0.0379605	total: 32.4s	remaining: 2m 17s
# 19:	learn: 0.0349198	total: 34.1s	remaining: 2m 16s
# 20:	learn: 0.0329430	total: 35.8s	remaining: 2m 14s
# 21:	learn: 0.0308997	total: 37.5s	remaining: 2m 13s
# 22:	learn: 0.0289624	total: 39.2s	remaining: 2m 11s
# 23:	learn: 0.0274351	total: 40.8s	remaining: 2m 9s
# 24:	learn: 0.0262547	total: 42.5s	remaining: 2m 7s
# 25:	learn: 0.0246453	total: 44.2s	remaining: 2m 5s
# 26:	learn: 0.0234958	total: 45.8s	remaining: 2m 3s
# 27:	learn: 0.0224278	total: 47.5s	remaining: 2m 2s
# ...
# 93:	learn: 0.0016671	total: 2m 41s	remaining: 10.3s
# 94:	learn: 0.0016460	total: 2m 43s	remaining: 8.58s
# 95:	learn: 0.0016459	total: 2m 44s	remaining: 6.87s
# 96:	learn: 0.0016191	total: 2m 46s	remaining: 5.15s
# 97:	learn: 0.0016114	total: 2m 48s	remaining: 3.43s
# 98:	learn: 0.0016108	total: 2m 50s	remaining: 1.72s
# 99:	learn: 0.0016104	total: 2m 51s	remaining: 0us
# 0:	learn: 0.4456978	total: 1.69s	remaining: 2m 47s
# 1:	learn: 0.3042437	total: 3.34s	remaining: 2m 43s
# 2:	learn: 0.2103272	total: 5s	remaining: 2m 41s
# 3:	learn: 0.1561106	total: 6.73s	remaining: 2m 41s
# 4:	learn: 0.1227566	total: 8.53s	remaining: 2m 42s
# 5:	learn: 0.0998211	total: 10.3s	remaining: 2m 40s
# 6:	learn: 0.0834939	total: 12s	remaining: 2m 39s
# 7:	learn: 0.0703639	total: 13.7s	remaining: 2m 37s
# 8:	learn: 0.0581775	total: 15.4s	remaining: 2m 35s
# 9:	learn: 0.0508654	total: 17.1s	remaining: 2m 33s
# 10:	learn: 0.0435915	total: 18.8s	remaining: 2m 32s
# 11:	learn: 0.0388859	total: 20.5s	remaining: 2m 30s
# 12:	learn: 0.0346337	total: 22.2s	remaining: 2m 28s
# 13:	learn: 0.0309451	total: 23.9s	remaining: 2m 26s
# 14:	learn: 0.0282138	total: 25.7s	remaining: 2m 25s
# 15:	learn: 0.0258059	total: 27.4s	remaining: 2m 23s
# 16:	learn: 0.0231972	total: 29.1s	remaining: 2m 22s
# 17:	learn: 0.0213902	total: 30.8s	remaining: 2m 20s
# 18:	learn: 0.0199781	total: 32.5s	remaining: 2m 18s
# 19:	learn: 0.0186209	total: 34.2s	remaining: 2m 16s
# 20:	learn: 0.0175792	total: 35.9s	remaining: 2m 15s
# 21:	learn: 0.0164934	total: 37.6s	remaining: 2m 13s
# 22:	learn: 0.0154970	total: 39.3s	remaining: 2m 11s
# 23:	learn: 0.0144658	total: 41.1s	remaining: 2m 10s
# 24:	learn: 0.0135622	total: 42.8s	remaining: 2m 8s
# 25:	learn: 0.0127834	total: 44.5s	remaining: 2m 6s
# 26:	learn: 0.0122318	total: 46.2s	remaining: 2m 4s
# 27:	learn: 0.0117128	total: 47.9s	remaining: 2m 3s
# 28:	learn: 0.0110393	total: 49.6s	remaining: 2m 1s
# 29:	learn: 0.0103271	total: 51.2s	remaining: 1m 59s
# 30:	learn: 0.0098636	total: 52.9s	remaining: 1m 57s
# 31:	learn: 0.0095013	total: 54.6s	remaining: 1m 55s
# 32:	learn: 0.0090224	total: 56.3s	remaining: 1m 54s
# 33:	learn: 0.0086077	total: 58.1s	remaining: 1m 52s
# 34:	learn: 0.0082976	total: 59.8s	remaining: 1m 51s
# 35:	learn: 0.0079182	total: 1m 1s	remaining: 1m 49s
# 36:	learn: 0.0076554	total: 1m 3s	remaining: 1m 47s
# 37:	learn: 0.0072997	total: 1m 4s	remaining: 1m 45s
# 38:	learn: 0.0065683	total: 1m 6s	remaining: 1m 44s
# 39:	learn: 0.0062702	total: 1m 8s	remaining: 1m 42s
# 40:	learn: 0.0059977	total: 1m 9s	remaining: 1m 40s
# 41:	learn: 0.0057378	total: 1m 11s	remaining: 1m 39s
# 42:	learn: 0.0056111	total: 1m 13s	remaining: 1m 37s
# 43:	learn: 0.0054509	total: 1m 15s	remaining: 1m 35s
# 44:	learn: 0.0052719	total: 1m 16s	remaining: 1m 34s
# 45:	learn: 0.0051409	total: 1m 18s	remaining: 1m 32s
# 46:	learn: 0.0050367	total: 1m 20s	remaining: 1m 30s
# 47:	learn: 0.0048902	total: 1m 21s	remaining: 1m 28s
# 48:	learn: 0.0047961	total: 1m 23s	remaining: 1m 27s
# 49:	learn: 0.0042989	total: 1m 25s	remaining: 1m 25s
# 50:	learn: 0.0041118	total: 1m 27s	remaining: 1m 23s
# 51:	learn: 0.0038877	total: 1m 28s	remaining: 1m 22s
# 52:	learn: 0.0037205	total: 1m 30s	remaining: 1m 20s
# 53:	learn: 0.0035872	total: 1m 32s	remaining: 1m 18s
# 54:	learn: 0.0034173	total: 1m 34s	remaining: 1m 16s
# 55:	learn: 0.0032953	total: 1m 35s	remaining: 1m 15s
# 56:	learn: 0.0030435	total: 1m 37s	remaining: 1m 13s
# 57:	learn: 0.0029441	total: 1m 39s	remaining: 1m 11s
# 58:	learn: 0.0028337	total: 1m 40s	remaining: 1m 9s
# 59:	learn: 0.0027500	total: 1m 42s	remaining: 1m 8s
# 60:	learn: 0.0026761	total: 1m 44s	remaining: 1m 6s
# 61:	learn: 0.0025975	total: 1m 45s	remaining: 1m 4s
# 62:	learn: 0.0025474	total: 1m 47s	remaining: 1m 3s
# 63:	learn: 0.0024562	total: 1m 49s	remaining: 1m 1s
# 64:	learn: 0.0023644	total: 1m 50s	remaining: 59.7s
# 65:	learn: 0.0022803	total: 1m 52s	remaining: 58s
# 66:	learn: 0.0022043	total: 1m 54s	remaining: 56.3s
# 67:	learn: 0.0021698	total: 1m 55s	remaining: 54.5s
# 68:	learn: 0.0021160	total: 1m 57s	remaining: 52.8s
# 69:	learn: 0.0020656	total: 1m 59s	remaining: 51.1s
# 70:	learn: 0.0019970	total: 2m 1s	remaining: 49.5s
# 71:	learn: 0.0019970	total: 2m 2s	remaining: 47.8s
# 72:	learn: 0.0019970	total: 2m 4s	remaining: 46.1s
# 73:	learn: 0.0019967	total: 2m 6s	remaining: 44.3s
# 74:	learn: 0.0019433	total: 2m 7s	remaining: 42.6s
# 75:	learn: 0.0019433	total: 2m 9s	remaining: 40.9s
# 76:	learn: 0.0019133	total: 2m 11s	remaining: 39.2s
# 77:	learn: 0.0019130	total: 2m 12s	remaining: 37.5s
# 78:	learn: 0.0019063	total: 2m 14s	remaining: 35.8s
# 79:	learn: 0.0019062	total: 2m 16s	remaining: 34.1s
# 80:	learn: 0.0019062	total: 2m 18s	remaining: 32.4s
# 81:	learn: 0.0018591	total: 2m 19s	remaining: 30.7s
# 82:	learn: 0.0018273	total: 2m 21s	remaining: 29s
# 83:	learn: 0.0017861	total: 2m 23s	remaining: 27.3s
# 84:	learn: 0.0017858	total: 2m 25s	remaining: 25.6s
# 85:	learn: 0.0017857	total: 2m 26s	remaining: 23.9s
# 86:	learn: 0.0017857	total: 2m 28s	remaining: 22.2s
# 87:	learn: 0.0017857	total: 2m 30s	remaining: 20.5s
# 88:	learn: 0.0017343	total: 2m 31s	remaining: 18.8s
# 89:	learn: 0.0017340	total: 2m 33s	remaining: 17.1s
# 90:	learn: 0.0017260	total: 2m 35s	remaining: 15.4s
# 91:	learn: 0.0016861	total: 2m 37s	remaining: 13.7s
# 92:	learn: 0.0016559	total: 2m 38s	remaining: 11.9s
# 93:	learn: 0.0016553	total: 2m 40s	remaining: 10.2s
# 94:	learn: 0.0016365	total: 2m 42s	remaining: 8.53s
# 95:	learn: 0.0016366	total: 2m 43s	remaining: 6.82s
# 96:	learn: 0.0016362	total: 2m 45s	remaining: 5.11s
# 97:	learn: 0.0016256	total: 2m 47s	remaining: 3.41s
# 98:	learn: 0.0016191	total: 2m 48s	remaining: 1.71s
# 99:	learn: 0.0016187	total: 2m 50s	remaining: 0us
# 0:	learn: 0.4317176	total: 1.73s	remaining: 2m 51s
# 1:	learn: 0.2834879	total: 3.46s	remaining: 2m 49s
# 2:	learn: 0.2032244	total: 5.18s	remaining: 2m 47s
# 3:	learn: 0.1498498	total: 6.85s	remaining: 2m 44s
# 4:	learn: 0.1174698	total: 8.54s	remaining: 2m 42s
# 5:	learn: 0.0972283	total: 10.2s	remaining: 2m 40s
# 6:	learn: 0.0820303	total: 11.9s	remaining: 2m 38s
# 7:	learn: 0.0690184	total: 13.8s	remaining: 2m 38s
# 8:	learn: 0.0586118	total: 15.5s	remaining: 2m 36s
# 9:	learn: 0.0514924	total: 17.2s	remaining: 2m 34s
# 10:	learn: 0.0450268	total: 18.9s	remaining: 2m 33s
# 11:	learn: 0.0387322	total: 20.6s	remaining: 2m 30s
# 12:	learn: 0.0352846	total: 22.3s	remaining: 2m 29s
# 13:	learn: 0.0314622	total: 24s	remaining: 2m 27s
# 14:	learn: 0.0290521	total: 25.7s	remaining: 2m 25s
# 15:	learn: 0.0266404	total: 27.4s	remaining: 2m 23s
# 16:	learn: 0.0249163	total: 29.2s	remaining: 2m 22s
# 17:	learn: 0.0224581	total: 31s	remaining: 2m 21s
# 18:	learn: 0.0210435	total: 32.7s	remaining: 2m 19s
# 19:	learn: 0.0191926	total: 34.4s	remaining: 2m 17s
# 20:	learn: 0.0180499	total: 36s	remaining: 2m 15s
# 21:	learn: 0.0169257	total: 37.8s	remaining: 2m 13s
# 22:	learn: 0.0159063	total: 39.5s	remaining: 2m 12s
# 23:	learn: 0.0149396	total: 41.2s	remaining: 2m 10s
# 24:	learn: 0.0141180	total: 42.9s	remaining: 2m 8s
# 25:	learn: 0.0135087	total: 44.6s	remaining: 2m 7s
# 26:	learn: 0.0128540	total: 46.5s	remaining: 2m 5s
# 27:	learn: 0.0122893	total: 48.2s	remaining: 2m 4s
# 28:	learn: 0.0117280	total: 50s	remaining: 2m 2s
# 29:	learn: 0.0109879	total: 51.7s	remaining: 2m
# 30:	learn: 0.0102065	total: 53.4s	remaining: 1m 58s
# 31:	learn: 0.0097315	total: 55s	remaining: 1m 56s
# 32:	learn: 0.0093500	total: 56.7s	remaining: 1m 55s
# 33:	learn: 0.0087733	total: 58.5s	remaining: 1m 53s
# 34:	learn: 0.0084399	total: 1m	remaining: 1m 51s
# 35:	learn: 0.0080026	total: 1m 1s	remaining: 1m 50s
# 36:	learn: 0.0076662	total: 1m 3s	remaining: 1m 48s
# 37:	learn: 0.0072988	total: 1m 5s	remaining: 1m 46s
# 38:	learn: 0.0070377	total: 1m 7s	remaining: 1m 45s
# 39:	learn: 0.0067321	total: 1m 8s	remaining: 1m 43s
# 40:	learn: 0.0065861	total: 1m 10s	remaining: 1m 41s
# 41:	learn: 0.0063535	total: 1m 12s	remaining: 1m 39s
# 42:	learn: 0.0062040	total: 1m 13s	remaining: 1m 37s
# 43:	learn: 0.0060294	total: 1m 15s	remaining: 1m 35s
# 44:	learn: 0.0058712	total: 1m 17s	remaining: 1m 34s
# 45:	learn: 0.0056201	total: 1m 18s	remaining: 1m 32s
# 46:	learn: 0.0054861	total: 1m 20s	remaining: 1m 30s
# 47:	learn: 0.0053680	total: 1m 22s	remaining: 1m 29s
# 48:	learn: 0.0051949	total: 1m 23s	remaining: 1m 27s
# 49:	learn: 0.0050515	total: 1m 25s	remaining: 1m 25s
# 50:	learn: 0.0048896	total: 1m 27s	remaining: 1m 23s
# 51:	learn: 0.0047883	total: 1m 28s	remaining: 1m 22s
# 52:	learn: 0.0045829	total: 1m 30s	remaining: 1m 20s
# 53:	learn: 0.0044821	total: 1m 32s	remaining: 1m 18s
# 54:	learn: 0.0042738	total: 1m 34s	remaining: 1m 16s
# 55:	learn: 0.0041460	total: 1m 35s	remaining: 1m 15s
# 56:	learn: 0.0040345	total: 1m 37s	remaining: 1m 13s
# 57:	learn: 0.0036926	total: 1m 39s	remaining: 1m 11s
# 58:	learn: 0.0035582	total: 1m 40s	remaining: 1m 9s
# 59:	learn: 0.0034396	total: 1m 42s	remaining: 1m 8s
# 60:	learn: 0.0033041	total: 1m 43s	remaining: 1m 6s
# 61:	learn: 0.0031423	total: 1m 45s	remaining: 1m 4s
# 62:	learn: 0.0030167	total: 1m 47s	remaining: 1m 2s
# 63:	learn: 0.0029129	total: 1m 49s	remaining: 1m 1s
# 64:	learn: 0.0028023	total: 1m 50s	remaining: 59.6s
# 65:	learn: 0.0027366	total: 1m 52s	remaining: 57.9s
# 66:	learn: 0.0026757	total: 1m 54s	remaining: 56.2s
# 67:	learn: 0.0025182	total: 1m 55s	remaining: 54.5s
# 68:	learn: 0.0024570	total: 1m 57s	remaining: 52.8s
# 69:	learn: 0.0024210	total: 1m 59s	remaining: 51s
# 70:	learn: 0.0023615	total: 2m	remaining: 49.3s
# 71:	learn: 0.0023616	total: 2m 2s	remaining: 47.6s
# 72:	learn: 0.0023003	total: 2m 4s	remaining: 45.9s
# 73:	learn: 0.0022326	total: 2m 5s	remaining: 44.2s
# 74:	learn: 0.0021664	total: 2m 7s	remaining: 42.5s
# 75:	learn: 0.0020714	total: 2m 9s	remaining: 40.8s
# 76:	learn: 0.0020188	total: 2m 10s	remaining: 39.1s
# 77:	learn: 0.0019554	total: 2m 12s	remaining: 37.4s
# 78:	learn: 0.0018663	total: 2m 14s	remaining: 35.6s
# 79:	learn: 0.0018663	total: 2m 15s	remaining: 33.9s
# 80:	learn: 0.0018663	total: 2m 17s	remaining: 32.2s
# 81:	learn: 0.0018405	total: 2m 19s	remaining: 30.5s
# 82:	learn: 0.0017920	total: 2m 20s	remaining: 28.8s
# 83:	learn: 0.0017920	total: 2m 22s	remaining: 27.1s
# 84:	learn: 0.0017920	total: 2m 24s	remaining: 25.5s
# 85:	learn: 0.0017920	total: 2m 25s	remaining: 23.8s
# 86:	learn: 0.0017474	total: 2m 27s	remaining: 22.1s
# 87:	learn: 0.0017472	total: 2m 29s	remaining: 20.4s
# 88:	learn: 0.0017467	total: 2m 30s	remaining: 18.7s
# 89:	learn: 0.0017466	total: 2m 32s	remaining: 17s
# 90:	learn: 0.0017464	total: 2m 34s	remaining: 15.3s
# 91:	learn: 0.0017080	total: 2m 36s	remaining: 13.6s
# 92:	learn: 0.0017079	total: 2m 37s	remaining: 11.9s
# 93:	learn: 0.0017078	total: 2m 39s	remaining: 10.2s
# 94:	learn: 0.0016751	total: 2m 41s	remaining: 8.48s
# 95:	learn: 0.0016743	total: 2m 42s	remaining: 6.78s
# 96:	learn: 0.0016743	total: 2m 44s	remaining: 5.09s
# 97:	learn: 0.0016589	total: 2m 46s	remaining: 3.39s
# 98:	learn: 0.0016585	total: 2m 47s	remaining: 1.69s
# 99:	learn: 0.0016582	total: 2m 49s	remaining: 0us
# 0:	learn: 0.5903135	total: 1.58s	remaining: 2m 36s
# 1:	learn: 0.5114048	total: 3.28s	remaining: 2m 40s
# 2:	learn: 0.4439811	total: 4.99s	remaining: 2m 41s
# 3:	learn: 0.3871720	total: 6.71s	remaining: 2m 41s
# 4:	learn: 0.3395837	total: 8.46s	remaining: 2m 40s
# 5:	learn: 0.3022160	total: 10.1s	remaining: 2m 38s
# 6:	learn: 0.2716382	total: 11.8s	remaining: 2m 37s
# 7:	learn: 0.2424305	total: 13.5s	remaining: 2m 35s
# 8:	learn: 0.2137481	total: 15.2s	remaining: 2m 34s
# 9:	learn: 0.1927723	total: 17.1s	remaining: 2m 33s
# 10:	learn: 0.1733552	total: 18.8s	remaining: 2m 32s
# 11:	learn: 0.1586543	total: 20.5s	remaining: 2m 30s
# 12:	learn: 0.1452361	total: 22.2s	remaining: 2m 28s
# 13:	learn: 0.1332139	total: 23.9s	remaining: 2m 26s
# 14:	learn: 0.1224761	total: 25.6s	remaining: 2m 24s
# 15:	learn: 0.1135072	total: 27.2s	remaining: 2m 22s
# 16:	learn: 0.1054629	total: 28.9s	remaining: 2m 21s
# 17:	learn: 0.0985899	total: 30.6s	remaining: 2m 19s
# 18:	learn: 0.0924244	total: 32.4s	remaining: 2m 18s
# 19:	learn: 0.0860795	total: 34.2s	remaining: 2m 16s
# 20:	learn: 0.0811196	total: 35.9s	remaining: 2m 15s
# 21:	learn: 0.0760870	total: 37.7s	remaining: 2m 13s
# 22:	learn: 0.0719016	total: 39.3s	remaining: 2m 11s
# 23:	learn: 0.0669640	total: 41s	remaining: 2m 9s
# 24:	learn: 0.0634676	total: 42.7s	remaining: 2m 8s
# 25:	learn: 0.0601261	total: 44.4s	remaining: 2m 6s
# 26:	learn: 0.0571694	total: 46.1s	remaining: 2m 4s
# 27:	learn: 0.0543394	total: 47.9s	remaining: 2m 3s
# 28:	learn: 0.0518391	total: 49.7s	remaining: 2m 1s
# 29:	learn: 0.0492679	total: 51.4s	remaining: 1m 59s
# 30:	learn: 0.0471738	total: 53.1s	remaining: 1m 58s
# 31:	learn: 0.0452761	total: 54.8s	remaining: 1m 56s
# 32:	learn: 0.0431013	total: 56.5s	remaining: 1m 54s
# 33:	learn: 0.0409892	total: 58.1s	remaining: 1m 52s
# 34:	learn: 0.0394837	total: 59.8s	remaining: 1m 51s
# 35:	learn: 0.0379650	total: 1m 1s	remaining: 1m 49s
# 36:	learn: 0.0364164	total: 1m 3s	remaining: 1m 47s
# 37:	learn: 0.0351232	total: 1m 4s	remaining: 1m 46s
# 38:	learn: 0.0338346	total: 1m 6s	remaining: 1m 44s
# 39:	learn: 0.0325843	total: 1m 8s	remaining: 1m 42s
# 40:	learn: 0.0314815	total: 1m 10s	remaining: 1m 40s
# 41:	learn: 0.0303450	total: 1m 11s	remaining: 1m 39s
# 42:	learn: 0.0294164	total: 1m 13s	remaining: 1m 37s
# 43:	learn: 0.0278920	total: 1m 15s	remaining: 1m 35s
# 44:	learn: 0.0271272	total: 1m 16s	remaining: 1m 33s
# 45:	learn: 0.0263070	total: 1m 18s	remaining: 1m 32s
# 46:	learn: 0.0255647	total: 1m 20s	remaining: 1m 30s
# 47:	learn: 0.0248514	total: 1m 22s	remaining: 1m 28s
# 48:	learn: 0.0241998	total: 1m 23s	remaining: 1m 27s
# 49:	learn: 0.0236387	total: 1m 25s	remaining: 1m 25s
# 50:	learn: 0.0230740	total: 1m 27s	remaining: 1m 23s
# 51:	learn: 0.0223872	total: 1m 28s	remaining: 1m 22s
# 52:	learn: 0.0218625	total: 1m 30s	remaining: 1m 20s
# 53:	learn: 0.0213019	total: 1m 32s	remaining: 1m 18s
# 54:	learn: 0.0207810	total: 1m 33s	remaining: 1m 16s
# 55:	learn: 0.0203092	total: 1m 35s	remaining: 1m 15s
# 56:	learn: 0.0198545	total: 1m 37s	remaining: 1m 13s
# 57:	learn: 0.0194742	total: 1m 39s	remaining: 1m 11s
# 58:	learn: 0.0189194	total: 1m 40s	remaining: 1m 10s
# 59:	learn: 0.0185059	total: 1m 42s	remaining: 1m 8s
# 60:	learn: 0.0180206	total: 1m 44s	remaining: 1m 6s
# 61:	learn: 0.0175781	total: 1m 45s	remaining: 1m 4s
# 62:	learn: 0.0171813	total: 1m 47s	remaining: 1m 3s
# 63:	learn: 0.0167689	total: 1m 49s	remaining: 1m 1s
# 64:	learn: 0.0164416	total: 1m 51s	remaining: 59.8s
# 65:	learn: 0.0160088	total: 1m 52s	remaining: 58.2s
# 66:	learn: 0.0156783	total: 1m 54s	remaining: 56.5s
# 67:	learn: 0.0154023	total: 1m 56s	remaining: 54.8s
# 68:	learn: 0.0150250	total: 1m 58s	remaining: 53s
# 69:	learn: 0.0147364	total: 1m 59s	remaining: 51.3s
# 70:	learn: 0.0144336	total: 2m 1s	remaining: 49.6s
# 71:	learn: 0.0141345	total: 2m 2s	remaining: 47.8s
# 72:	learn: 0.0138599	total: 2m 4s	remaining: 46.1s
# 73:	learn: 0.0135830	total: 2m 6s	remaining: 44.4s
# 74:	learn: 0.0132053	total: 2m 8s	remaining: 42.7s
# 75:	learn: 0.0129265	total: 2m 9s	remaining: 41s
# 76:	learn: 0.0126704	total: 2m 11s	remaining: 39.3s
# 77:	learn: 0.0124191	total: 2m 13s	remaining: 37.6s
# 78:	learn: 0.0121681	total: 2m 15s	remaining: 35.9s
# 79:	learn: 0.0119520	total: 2m 16s	remaining: 34.2s
# 80:	learn: 0.0116608	total: 2m 18s	remaining: 32.5s
# 81:	learn: 0.0113996	total: 2m 20s	remaining: 30.8s
# 82:	learn: 0.0112131	total: 2m 21s	remaining: 29s
# 83:	learn: 0.0109852	total: 2m 23s	remaining: 27.3s
# 84:	learn: 0.0107601	total: 2m 25s	remaining: 25.7s
# 85:	learn: 0.0103867	total: 2m 27s	remaining: 23.9s
# 86:	learn: 0.0101955	total: 2m 28s	remaining: 22.2s
# 87:	learn: 0.0099732	total: 2m 30s	remaining: 20.5s
# 88:	learn: 0.0097858	total: 2m 32s	remaining: 18.8s
# 89:	learn: 0.0096367	total: 2m 33s	remaining: 17.1s
# 90:	learn: 0.0094720	total: 2m 35s	remaining: 15.4s
# 91:	learn: 0.0092710	total: 2m 37s	remaining: 13.7s
# 92:	learn: 0.0090567	total: 2m 38s	remaining: 12s
# 93:	learn: 0.0088721	total: 2m 40s	remaining: 10.3s
# 94:	learn: 0.0087508	total: 2m 42s	remaining: 8.55s
# 95:	learn: 0.0086105	total: 2m 44s	remaining: 6.84s
# 96:	learn: 0.0084175	total: 2m 45s	remaining: 5.13s
# 97:	learn: 0.0082652	total: 2m 47s	remaining: 3.42s
# 98:	learn: 0.0081186	total: 2m 49s	remaining: 1.71s
# 99:	learn: 0.0080085	total: 2m 50s	remaining: 0us
# {'depth': 10, 'learning_rate': 0.1}
# f1-метрика: 0.9873887805271119
# Wall time: 45min 26s

# %% [markdown]
# ### LightGBM

# %%
parameters_lgbm = {'learning_rate' : [0.1, 0.2, 0.3]
                  }

# %%
# %%time

LGBMC = GridSearchCV(LGBMClassifier(), parameters_lgbm, scoring='f1')
LGBMC.fit(features_upsampled, target_upsampled)
best_model_lgbmc = LGBMC.best_estimator_
print(LGBMC.best_params_)
print('f1-метрика:', LGBMC.best_score_)
# Out:
# {'learning_rate': 0.1}
# f1-метрика: 0.9926631007400673
# Wall time: 40.1 s

# %% [markdown]
# ### Логистическая регрессия

# %%
parameters_lr = {'C': np.linspace(0.0001, 100, 20)}

# %%
# %%time

LR = GridSearchCV(LogisticRegression(), parameters_lr, scoring='f1')
LR.fit(features_upsampled, target_upsampled)
best_model_lr = LR.best_estimator_
print(LR.best_params_)
print('f1-метрика: ', LR.best_score_)
# Out:
# {'C': 10.526405263157894}
# f1-метрика:  0.9904654169360052
# Wall time: 21.3 s

# %% [markdown]
# ### Дерево решений

# %%
state = np.random.RandomState(12345)

# %%
parameters_dtc = {'max_depth': range (20, 80, 10),
                 'min_samples_leaf': range (1,10),
                 'min_samples_split': range(2,10)
                }

# %%
# %%time

DTC = GridSearchCV(DecisionTreeClassifier(random_state=state), parameters_dtc, scoring='f1')
DTC.fit(features_upsampled, target_upsampled)
best_model_dtc = DTC.best_estimator_
print(DTC.best_params_)
print('f1-метрика:', DTC.best_score_)
# Out:
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# f1-метрика: 0.9883103165587611
# Wall time: 6min 15s

# %% [markdown]
# ### Случайный лес

# %%
parameters_rfc = {'max_depth': range (20, 80, 10),
                 'n_estimators': [100, 200, 300]
                }

# %%
# %%time

RFC = GridSearchCV(RandomForestClassifier(random_state=state), parameters_rfc, scoring='f1')
RFC.fit(features_upsampled, target_upsampled)
best_model_rfc = RFC.best_estimator_
print(RFC.best_params_)
print('f1-метрика:', RFC.best_score_)
# Out:
# {'max_depth': 20, 'n_estimators': 100}
# f1-метрика: 0.9919252117537336
# Wall time: 1min 55s

# %% [markdown]
# ### Вывод

# %% [markdown]
# - По качеству почти все модели, кроме Дерева решений, достаточно эффективны, f1-метрика  у них больше 99. У модели Дерева решений f1-метрика самая низкая, поэтому эту модель использовать не рекомендуется.
# - По времени самой долгой получилась модель CatBoost, поэтому её использовать не рекомендуется.
# - Самой быстрой и качественной моделью получилась Логистическая регрессия с гиперпараметром `C`= 10.5. Проверим эту модель на тестовой выборке и сравним значение метрики f1 с Dummy-моделью.

# %% [markdown]
# ## Тестирование

# %%
# %%time

best_model_lr.fit(features_upsampled, target_upsampled)
prediction = best_model_lr.predict(features_test)
score_lr = f1_score(target_test, prediction)
print('f1-метрика на тестовой выборке:', score_lr.round(3))
# Out:
# f1-метрика на тестовой выборке: 0.842
# Wall time: 245 ms

# %%
dummy = DummyClassifier()
dummy.fit(features_upsampled, target_upsampled)
prediction_clf = dummy.predict(features_test)
score_test = f1_score(target_test, prediction_clf)
print('f1-метрика случайной модели на тестовой выборке:', score_test.round(3))
# Out:
# f1-метрика случайной модели на тестовой выборке: 0.0

# %% [markdown]
# ## Вывод

# %% [markdown]
# Для классификации комментариев на позитивные и негативные рекомендуется использовать модель Логистической регрессии с гиперпараметром C= 10.5, так как значение f1-метрики на обучающей выборке у неё самое большее, а времени на обучение и предсказание уходит мало.
#
# На тестовой выборке значение f1 у модели получилось 0.842, что соответствует условию поставленной задачи. Также модель прошла проверку на адекватность.
